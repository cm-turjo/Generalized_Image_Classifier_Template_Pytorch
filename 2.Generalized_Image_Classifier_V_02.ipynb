# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/flowers-dataset/README.dataset.txt
# /kaggle/input/flowers-dataset/README.roboflow.txt
# /kaggle/input/flowers-dataset/valid/dandelion/33857574164_b0b724b567_n_jpg.rf.7b99dd4c5c099777768ab5129a29d570.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/6495802659_98b57e0cca_m_jpg.rf.1095124909c35debcea108ed07d44eb9.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/15378782362_4161b23af7_m_jpg.rf.5660236373de659a56b40ae54cc25e61.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5607983792_f8b8766ff7_jpg.rf.011e016018d8373dccd60fe8440e0992.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3451646670_3eff7094b7_n_jpg.rf.392c7bc357ebcc2a645e68178f2cec0e.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3696596109_4c4419128a_m_jpg.rf.003cb976f4403bbf6aae622d629d9841.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2477231067_3aecef1bf8_n_jpg.rf.21cb5619be696e0ad2514e94537b766c.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2628514700_b6d5325797_n_jpg.rf.4248eeeba8c3b6c1fce3721c830c8472.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7132605107_f5e033d725_n_jpg.rf.edec3ea78cf1866a32bf243bac327be7.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/494108764_e00178af6e_jpg.rf.7bc719a775d24bf455c87eb38f09f78c.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34653465656_31bc613631_n_jpg.rf.1140db40c32e2636d82dfe138f46c674.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/501987276_744448580c_m_jpg.rf.e460fa007a89798f536a1db09014576d.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8475758_4c861ab268_m_jpg.rf.cd47010af2b20ec74e3a3d09f8120472.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4601270210_60136f2b87_n_jpg.rf.1a476803c0f820c9a139a51babdf4c72.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34343228430_8df9f1c03a_n_jpg.rf.43293bb1adc4e5af1be654bc776576b5.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7132677385_bcbdcc6001_jpg.rf.df3c23fa668c07341647a73fa058622a.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8270191872_61e47ae3b8_m_jpg.rf.46f2d3b1608731c9ad9c6540e210cede.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5762590366_5cf7a32b87_n_jpg.rf.9064fe42754f1a15ff968b1ce5f39468.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/13887066460_64156a9021_jpg.rf.7ee48e2e06fc05908ec261276ee8f1e7.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/19506262462_d0945c14a6_jpg.rf.ae3f6b80443e692c5e9a783abc1bc4de.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/98992760_53ed1d26a9_jpg.rf.5cd74883ab997ec1c3fdf62fabc4de3e.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4645161319_c308fc31ef_n_jpg.rf.591afd72a6120d80e0b4b572fc9bb3bf.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4290112545_3528055993_m_jpg.rf.450093d33c05a31ed72588ed2e235fa6.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/22190242684_8c3300d4e6_jpg.rf.75a54d0fc4c9a174e331766d1197d1e5.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8717161615_4c1e403083_jpg.rf.2e7be1d53869015506a888115f679517.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4632235020_d00ce1e497_jpg.rf.580b44f1f22d4b1ce8860de27c564a7d.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/151385302_f8980a257f_n_jpg.rf.dfcc33125591399df3faa7584901ea77.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2540640433_dedd577263_jpg.rf.055d14851de224595547f6ec4ba1f48b.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8647874151_aac8db2588_m_jpg.rf.607cc0a5c264b6fce2e8efd65d8a9dab.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4714026966_93846ddb74_m_jpg.rf.9b4fbb48218a325278be5981b1f90024.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2472641499_cbe617a93d_jpg.rf.385ae5ad860bf60cc545dd9b7c9ba556.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14469481104_d0e29f7ffd_jpg.rf.8f220af2953d67f53d2734d96df08851.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/19617425002_b914c1e2ab_jpg.rf.4ba867651fc3f260b2d85a15a29c84a9.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4562516418_8ccb8c103f_jpg.rf.2279c34d1c050ae9eb0efe05d2c0a58a.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4560613196_91a04f8dcf_m_jpg.rf.3aeb35e524be3032fcb44c884c92b318.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4657801292_73bef15031_jpg.rf.8b35ef4931d02bf4572486deea2b1d81.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4496277750_8c34256e28_jpg.rf.a036f2baebfec8c22a46e7cde0145369.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/9818247_e2eac18894_jpg.rf.4d3c4156e84e105433f528b712ff890f.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5628515159_6b437ff1e5_n_jpg.rf.c0f4d055d35de2eb4ac0879b7a4b2985.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8701999625_8d83138124_jpg.rf.c21e834fd11d66ed3cd8ab481237e8b6.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/141935731_d26d600f4f_m_jpg.rf.8f886721d427cb43adbe72ca505626a6.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/9301891790_971dcfb35d_m_jpg.rf.760ea1ad8facbaaf93fcaa322f815419.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4258272073_f616d1e575_m_jpg.rf.52baa30ffb80822d2bfb75402e464a61.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34334194690_0dfe3d8701_n_jpg.rf.5de31f8e7ad3aa9c81b3075f70964d7a.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5909154147_9da14d1730_n_jpg.rf.b6a4282f8cf0ee54bae42027c95ed005.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14829055_2a2e646a8f_m_jpg.rf.e7b82939f82ef450acccaec9ff5cdfbd.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/29138994986_267e0e36c9_n_jpg.rf.66321e343148501cd2c6438e9e458b52.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8194560480_bfc1fb5801_jpg.rf.76f28c98939b260e0c9c6f46913f2524.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34335432530_cd667cbb19_n_jpg.rf.43815811b073e764f65e351d83c1e65c.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14740350060_a489d9fa06_jpg.rf.e490cc03192f1a5d69339b512fa00d2b.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4607183665_3472643bc8_jpg.rf.a790448de748de87a238714400770683.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2995221296_a6ddaccc39_jpg.rf.4f076325527f023ae451059e39c991ff.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/151861297_55b10a03a6_n_jpg.rf.09e308a9bc85c7a88e72400d78c8aec1.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/1443259657_2704fab26e_n_jpg.rf.a7a59da405d43e92a3fa749f1d1ea4c5.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/18111636378_856027a7b8_n_jpg.rf.b554e7b8f7d98498d6e54ae7366c7a04.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7950892504_33142110c2_jpg.rf.59d55382dc6eb96075c104a22ba03f8a.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/6985099958_5249a4688b_jpg.rf.7adf8b6822bf57e04edcfcc4908bb3a8.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/17244252705_328e0bcda6_jpg.rf.3abea371ef8c73f6b9af8fb4e7f80424.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34724303275_b9494837aa_n_jpg.rf.1d0bdd12cec969f45c7cd607b11290ff.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/139124974_9e3ba69f6c_jpg.rf.06edf791b14fef93c670dafceffc77dc.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/17080000869_a80e767f4a_m_jpg.rf.9fe7cb57193ec86a7772901b8c7b36d0.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4847150510_7a5db086fa_jpg.rf.5f6cee2e1edcc8d9fc145e0e9bb79bf4.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8740787470_67230d0609_jpg.rf.e978fda923673d20f193d524cf154d0e.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34686041416_e50c8028f9_n_jpg.rf.b94587ea842ebdde79ca3f8a94003441.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8181477_8cb77d2e0f_n_jpg.rf.2d73b401a455c849dcee08f4c74cad9d.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14065420729_9b388bf7cb_m_jpg.rf.097a92b2851f6ed080f883441af3c3f6.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34692530906_fe2470a5e5_n_jpg.rf.f9d6785be023790faf8fd614d8ded9ae.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14053397367_75cba846eb_n_jpg.rf.f528ec704a774927e4a5fe6cb96e1aa1.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7196409186_a59957ce0b_m_jpg.rf.582d2a056a0f524589c9fe2606397e32.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34722644565_812fcc1397_n_jpg.rf.2171bbd61d5323545936d4c0a1ab87ca.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7083589767_2859993846_n_jpg.rf.ce03f7ea0d529cf251b8da0b9642670f.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/18001393975_2a6acaabd8_jpg.rf.134ba0bb786ef7005d9b1b2a838a3dd8.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/6953830582_8525e0423c_n_jpg.rf.e4e349be90248b397b38a3cb78a46737.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8267315764_129f2e1d77_m_jpg.rf.5531f748ef7f27c30cd75cc7457b5f82.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3675486971_d4c8683b54_n_jpg.rf.4c4a05ea0b66fe9f4a3fa56528f500e6.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3562861685_8b8d747b4d_jpg.rf.4361b0785e5ec39e2e9524e1fbd5419d.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5726984343_ae124aed97_jpg.rf.1b3d3667674cb3dbf0a9a30fc67b3b92.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/18996760154_58d3c48604_jpg.rf.4517620ef6bdb434da220fb2788bc669.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7162551630_3647eb9254_jpg.rf.e0f22e5d7f06a405a17e68274442d993.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7808545612_546cfca610_m_jpg.rf.74fadec9b60349f782876b714d9759b4.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/10919961_0af657c4e8_jpg.rf.d527609365d174a511758b40fdc53834.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3454102259_957ecd0a9b_jpg.rf.502dc93094f0fc086b27f318abbe413c.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/33925191623_d355f976ef_n_jpg.rf.6d05942a7a6eade54858343b80d29f23.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3483575184_cb8d16a083_n_jpg.rf.173790a2ba84c1b831959467d068dc80.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4629844753_4e02015d29_m_jpg.rf.b90f77d521d9c593b4ef500611458169.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/19440910519_cb1162470e_jpg.rf.41d5fcceb0eb206322bc56fa28195a7c.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7950901292_2dea05f9a2_n_jpg.rf.392a93e8e7b567696858a15daeca8301.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/16699732794_5bfd639cf8_n_jpg.rf.64778e4df3054200f02844b530ecfc20.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/6250363717_17732e992e_n_jpg.rf.e2b0456f3b29ba134f1f73650a5514b8.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34550871222_a9d795a2c0_n_jpg.rf.922561872b156c964c9e1bd596e3203c.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4691257171_23a29aaa33_n_jpg.rf.33a8cc76c36b999663ddfc1b0646ce87.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/18243351371_5fda92ac0a_n_jpg.rf.c49911e54ff726d57ce4250d4291bce1.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4530848609_02a1d9b791_jpg.rf.1f606f7bc7e464733fd5946957b7833f.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34571238031_7eff74ca43_n_jpg.rf.4b34bccc31ed72da801b7a236937bd6f.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3451079245_2139200d66_n_jpg.rf.25340a1e9b0544a7014672e274e20eb6.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14093744313_b66bc95072_jpg.rf.0019ff83664af459f614ad9302419a2c.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8717157979_05cbc10cc1_jpg.rf.4b7d0aa4b1d4df60cbba4879700292ad.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3418355347_2bdcca592a_jpg.rf.cfaa2132ca6da01e6af9eea32f0ca6d3.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/80846315_d997645bea_n_jpg.rf.cb1b888d4f96eb49d094e649b93368fa.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/23192507093_2e6ec77bef_n_jpg.rf.a718a2742298d729d64c7c304d0715ed.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/33869330174_b259025135_n_jpg.rf.f81be0ce6439b45c8319ba377e1daedb.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34728513735_ebb4b179eb_n_jpg.rf.dcacde5c59bbb77f449eb0d020811788.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34587934371_1a0429111e_n_jpg.rf.ea47048bc0cf6ad4fa2a0c125507d8f9.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8979087213_28f572174c_jpg.rf.e5cb9f7085e91720784066241eda9b19.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5767676943_4f9c7323f3_n_jpg.rf.10d74f0ef934ca335e3a7a488c465fde.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34694287966_43ce068108_n_jpg.rf.0f618b7a2f42ea085d3c25d910feb5cf.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4669006062_6b3d260037_n_jpg.rf.82cde4741ebb902da75bf5af341b5bc4.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/142813254_20a7fd5fb6_n_jpg.rf.43976102044e305a48e0905db478f529.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14306875733_61d71c64c0_n_jpg.rf.2dc32140ac4ebca9f351dfd49744918f.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/33904560113_497239a68f_n_jpg.rf.c48d8f4f65da16af36f68eff5fe6c52e.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4589787911_851cb80157_n_jpg.rf.df15705fc4e103e299809c6beeb8a01a.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7308600792_27cff2f73f_jpg.rf.8b043e8895ff25b4b544ba3cf6747699.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4558562689_c8e2ab9f10_jpg.rf.35909170dd91d544857b179051882921.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34551666432_c5b5f9684e_n_jpg.rf.c586aecb83150d61f68f387be66bce00.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/6104442744_ee2bcd32e7_n_jpg.rf.b534452697cbbb9d158d20448e495b05.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3581252194_8c976d333a_n_jpg.rf.262a5e54bda59dec5177396e66822350.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/11124381625_24b17662bd_n_jpg.rf.dcf5bd7b8395099f500bea7dc04f5def.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14886860069_b84665a073_jpg.rf.4db9e880b60dd13ab00fdc64dbe2814f.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/19526570282_1d1e71b0f3_m_jpg.rf.9f862038c70de449166461c08b29ca42.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4552571121_2677bcdec3_jpg.rf.c205a14542abf77e23076c779be1aa30.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/13967344688_aa629dcdee_n_jpg.rf.19e501c8987fe602cb2b082dddc09437.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3954167682_128398bf79_m_jpg.rf.7b8de7b13b2edcefe7ecaf3bf324a763.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3539077354_c67aa7168d_m_jpg.rf.0a59b9f6706708a198c3f1d10bddd6d1.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34562347042_e4dc06879a_n_jpg.rf.c06a382facb495319d07a6fb8cae6306.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/1273326361_b90ea56d0d_m_jpg.rf.7a22d4efa756028d17cc523de5740bd6.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/16650892835_9228a3ef67_m_jpg.rf.de1c92ca3a9c8008a929c707f50fe056.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/483097906_2c35054346_jpg.rf.4628346e95fc682b71f972768c7cfe7e.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/19593576916_f5a083d7fe_n_jpg.rf.e92e14397eef8602de53eaed673063c6.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/13386618495_3df1f1330d_jpg.rf.56a391d64af0c5b6ff4119d58615bc94.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/155646858_9a8b5e8fc8_jpg.rf.45bf7b349857c779337090b1ca73b217.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5655177340_78fc36ce59_m_jpg.rf.57a28c729419f6afad9062281f5bc4cf.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14313509432_6f2343d6c8_m_jpg.rf.01497ce162dea438d1246fdfeadbf8c0.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14439618952_470224b89b_n_jpg.rf.5f06063a970a53ceace442c9fbb2a609.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/33885269993_3968e1aacc_n_jpg.rf.3f98414d9ad10ce85f2c1acfc2b6eea4.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8209318399_ae72aefdb5_jpg.rf.fc1e6fd036286f5ea56c3314c556ccc0.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7280227122_7ea2bef7f4_n_jpg.rf.48a72ef097cda874da8a1e58a09ec1d1.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14886963928_d4856f1eb6_n_jpg.rf.3a41a2400949e624ec708c2ca12ed756.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5110104894_a52c685516_n_jpg.rf.43caea3a62bb363d388668229b9407c8.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/17388674711_6dca8a2e8b_n_jpg.rf.3aa27a620511c516583009b27429addc.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/1469549847_eac61a6802_jpg.rf.33c6c1f63c0548925e9b270f7f1ae138.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14128839257_23def53028_jpg.rf.2060807da621e2851ff481a1ee527032.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5605502523_05acb00ae7_n_jpg.rf.bb6a0022a32bc20859e345ffd62a5b02.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2326334426_2dc74fceb1_jpg.rf.49ac96508c76f847d1d9977909b5005e.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5623855601_ecaebdb8fe_jpg.rf.c054889bc7ba8a6b1a1c6d6ac10347db.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2444241718_3ca53ce921_jpg.rf.79d31ca3b8296b9312581f01d45ab925.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/138132145_782763b84f_m_jpg.rf.1b55e35f7f455a43bbe36c8803de7eaf.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/19691175559_ef12b8b354_n_jpg.rf.5e8c04b3bb5d411c225fd3420ad55283.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3464015936_6845f46f64_jpg.rf.4b0f488e7ac245798930acd8206f3df9.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/17862580326_293070978d_m_jpg.rf.3da14ed9e3d81d1102da9ed6992c6dff.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5598845098_13e8e9460f_jpg.rf.74279a14093ce2bc23fc42484180e895.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/501987288_c69c4e0c90_m_jpg.rf.6026d37f308e00682e5c9877ab549112.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8740218495_23858355d8_n_jpg.rf.17d7f264bf98f376c2e83bf5978bd0d1.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2512977446_ac498955ee_jpg.rf.983d340fb6bbb0a75d157b4b6cae416a.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5045509402_6e052ce443_jpg.rf.498af212ff1a9d465e669f75c20b4e4b.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/19961979110_fcd8092388_m_jpg.rf.65a165d6774c0586dc273457b762bde1.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/17420983523_2e32d70359_jpg.rf.2b98bd5210890e6cfebbbd6ba02b2bb6.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2469856983_fe8e36ba57_jpg.rf.74ee1502f9df99e534bd8cc88abffdfa.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5109501167_2d9bbb0f27_m_jpg.rf.9d6ceccd0868ea253ba2ec5e23e6470d.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7884440256_91c033732d_jpg.rf.5d311d41a9bb1dbc7213b624fc28108b.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34586667251_bfda649f33_n_jpg.rf.cb2d8cf6470dde5c70c94b354a75f459.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/340190928_d77bf4d615_jpg.rf.4c536b71ac733083357539a318b8d875.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/20983660733_06b35b9eb8_jpg.rf.bc85b88e6cc658055167dec24590d09d.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/1128626197_3f52424215_n_jpg.rf.c367df23bcccac3fe70dcc6b36b379bd.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2476098674_e6f39536f5_n_jpg.rf.c4993f9ddd7ca34118d4d4cf4adafe64.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/16970837587_4a9d8500d7_jpg.rf.566e636e2ccc6cdc3dca1825f32d52fe.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3844111216_742ea491a0_jpg.rf.5137ddd3390093404f9f2212c3d36741.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/17367866236_61abd4d243_n_jpg.rf.d1df6f1e3795ad2a7ab185df303f9453.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2467980325_237b14c737_m_jpg.rf.7305eac1c87991681a7f458209882b30.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/9726260379_4e8ee66875_m_jpg.rf.09135060240a38642adf636a27c78387.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/6994931380_a7588c1192_m_jpg.rf.b980f94f75d690f29691ce133f5e12e0.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4598938531_9749b3b56a_jpg.rf.dab89926cab465b00502ef13a3410753.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/19551343814_48f764535f_m_jpg.rf.f92f515479a7421b9e02acd88d426d24.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/7164500544_332b75aa3b_jpg.rf.a2778b619a55b108e2b3e2ce65688bda.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2622697182_ea4aff29dd_n_jpg.rf.006213ec57786158e0a338090e2df094.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3998927705_af499a4f29_jpg.rf.53f3f58c478e2346559c0cae8a70c208.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3469112805_6cc8640236_jpg.rf.b02e2169b00148b76fccaffe971ba454.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/16691236594_4287cea9d6_n_jpg.rf.d27f2ad7febb8270ddb10aa1d1b0c741.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/17075803866_aeeded2637_jpg.rf.59a9934a6d8cc12bc651d2424b47a143.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/4944731313_023a0508fd_n_jpg.rf.90af0636cc3f0cde64634fd4d2cb83d1.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5675705011_82729927ca_n_jpg.rf.7202328057fd386c2d6c4c399e6c5602.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2693136371_dde2570813_jpg.rf.2e1933435406a36fc22cba8ccd4bb250.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8842482175_92a14b4934_m_jpg.rf.772f9c2dab1d84dc54da4666e2f24ec7.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/8738317694_eca2ce3bfc_n_jpg.rf.bd1c832bf41a1987bb46ed5ba05f3535.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2133943140_9fc7bcc9aa_jpg.rf.96f25b2b50350d1e2e8dbecb0372015f.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34694292346_83b4d97809_n_jpg.rf.f9ecdfbf87b91ad079bb44b08099c610.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/33877696673_2d1de2d252_n_jpg.rf.2047cb00d659135805d32def63a0c23f.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3554992110_81d8c9b0bd_m_jpg.rf.fc2868f4633e3f32e1a4f7b0a674c152.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/5673112305_02fe19297b_n_jpg.rf.e06133900b82be415cb00e5e0e74a50f.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2470874500_43d8011e75_jpg.rf.a5b859e7e938574529b6a0886632dd05.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2335702923_decb9a860b_m_jpg.rf.fb34df384bcd8d5c7130519f817fa933.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/32120685303_90b5f21ab2_n_jpg.rf.4729e6a4c91ce173f8519af52d8b564f.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/21523597492_39b6765cd7_m_jpg.rf.804126c29fb0ce02afa347f80bfb7a73.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/136999986_e410a68efb_n_jpg.rf.502dc43fd285faeef9c89ffe63f5a520.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/10779476016_9130714dc0_jpg.rf.3c7e68dd5e1aee875b933f3dd9d0d5b1.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34561332721_04b6f1c889_n_jpg.rf.37079d1a648a7e643840203b470d4a49.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/10200780773_c6051a7d71_n_jpg.rf.ff5edd069ad59c00902c43e589aff9b4.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/3664916269_29f07c7c7b_jpg.rf.c867f0a27e2f383c0491dca7affe9fec.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34323484476_6406ee1e37_n_jpg.rf.2b2b09f98ffb8aa8912cee0720027286.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/2395009660_295c8ffd67_m_jpg.rf.05b1681057ebf4fbf9ba1ae72e694cdc.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/14003401241_543535b385_jpg.rf.0ba300cd08b6e1b33fe40163f576a378.jpg
# /kaggle/input/flowers-dataset/valid/dandelion/34690508115_bafcb9845c_n_jpg.rf.fab2c6d48b2817f3cfb2520d19e7582d.jpg
# /kaggle/input/flowers-dataset/valid/daisy/12601254324_3cb62c254a_m_jpg.rf.813ccf6f0d9cf525b51c50cd00e5f0a1.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3379332157_04724f6480_jpg.rf.651717a3182afb7d29a3122e42088d39.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34293312980_5f6c492c52_n_jpg.rf.664de78fe41d00d62425acf235d43a3d.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34727863665_b00ac77266_n_jpg.rf.6701e34653fd671b0ee56a1987fa28a6.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5434742166_35773eba57_m_jpg.rf.27e42329ede24824860b00caa92c6518.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3533954656_79156c8473_jpg.rf.e1d05a965e22515ed1f95e4494f89a8e.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34300874850_923cc2881c_n_jpg.rf.5c16e0fa5563d0fe6e55cf8c15d04755.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2828733818_1c1ed0089d_n_jpg.rf.fdaacac3363ca8c39c2d7f355edefb91.jpg
# /kaggle/input/flowers-dataset/valid/daisy/14088053307_1a13a0bf91_n_jpg.rf.4c3cdc6ecfb6e4fbd8a718124cb043ae.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2573240560_ff7ffdd449_jpg.rf.11d1996f7f3d26bdfc6020e5ce3be6a5.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3336704121_cfeb67a7d7_jpg.rf.a61c5f86d2ddb90699008a8163ea5b9c.jpg
# /kaggle/input/flowers-dataset/valid/daisy/705422469_ffa28c566d_jpg.rf.7b7f83f5c54bbe5beaa0e6f6bda7f756.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2812442552_3eed5fb9f2_m_jpg.rf.f93bc521ceae4afdd2dcdfdde95e771c.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5623010186_796ca8d29a_jpg.rf.1c9e00b6b5420bc5f8c0113252a35315.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34566613262_fefbcc279a_n_jpg.rf.ddcc3afd7addcbed656f9142f17c47d9.jpg
# /kaggle/input/flowers-dataset/valid/daisy/33863293993_3ed7515936_n_jpg.rf.d25b0140a0a0bd0b2d37f2c6f6067b5b.jpg
# /kaggle/input/flowers-dataset/valid/daisy/10555815624_dc211569b0_jpg.rf.51b3ab04fd97acd13cdebb3aa2d11dbe.jpg
# /kaggle/input/flowers-dataset/valid/daisy/18711159980_11d3bd5042_jpg.rf.9ad603dcb68121fcc70a94a2a1daf01a.jpg
# /kaggle/input/flowers-dataset/valid/daisy/14921511479_7b0a647795_jpg.rf.eef04b31cccfa553517ee65e637646f0.jpg
# /kaggle/input/flowers-dataset/valid/daisy/20182559506_40a112f762_jpg.rf.03c7de8ea6580bbdf89245944baf9343.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2019064575_7656b9340f_m_jpg.rf.2d417274746c782e435e014fd61add56.jpg
# /kaggle/input/flowers-dataset/valid/daisy/16323838000_3818bce5c6_n_jpg.rf.23a0cb3c8aa1ef099deaea62d36fa8ef.jpg
# /kaggle/input/flowers-dataset/valid/daisy/8671824531_64b816949e_m_jpg.rf.37d56da9b7507cab09ff3d8d56894a1c.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5133243796_44de429de5_m_jpg.rf.a477b1c9d30930f82eedda624d7b66c3.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2599662355_7782218c83_jpg.rf.8cbb05b1a5029c198a3798f67e3a4a80.jpg
# /kaggle/input/flowers-dataset/valid/daisy/18679421522_3be9879e32_jpg.rf.71b6281598440de36c1583b866f8f5af.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2513618768_ff7c004796_m_jpg.rf.6dabe16796e47d473f77b470b759b6d4.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5740004086_690a1eef85_n_jpg.rf.7d6db0b71a5f1d552655ca565323ea45.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5054771689_00dd40b971_n_jpg.rf.90c07bac4a063344abaac7269d263715.jpg
# /kaggle/input/flowers-dataset/valid/daisy/14507818175_05219b051c_m_jpg.rf.3b04f0b1aadf954164f74e48f4acf4f9.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5896680664_641de2de5a_n_jpg.rf.aa0a1dd23c68079db69bf82855ab3539.jpg
# /kaggle/input/flowers-dataset/valid/daisy/19975899671_ebc42b7865_n_jpg.rf.b54dd73a9197efddbea56163263cc8f5.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2349640101_212c275aa7_jpg.rf.17f4610a82403de87fd568c25590959b.jpg
# /kaggle/input/flowers-dataset/valid/daisy/4584890753_14ea24a619_n_jpg.rf.c0eee91e2274bc9d47106b47b98c2532.jpg
# /kaggle/input/flowers-dataset/valid/daisy/14332947164_9b13513c71_m_jpg.rf.d35430c426788f82287f1786ccf49c1a.jpg
# /kaggle/input/flowers-dataset/valid/daisy/9922116524_ab4a2533fe_n_jpg.rf.300dd991f1ee7f49f3a544165db04668.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5794839_200acd910c_n_jpg.rf.7e1ca3c24b13bb849bbbaabcf47b119a.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5944315415_2be8abeb2f_m_jpg.rf.a73cbc1bdae609c0fe896b545d3265e2.jpg
# /kaggle/input/flowers-dataset/valid/daisy/169371301_d9b91a2a42_jpg.rf.58fab26a8e228e87ec24e221143ff07b.jpg
# /kaggle/input/flowers-dataset/valid/daisy/33807950584_f5b63715e4_n_jpg.rf.afd1f42a8a9c15e2e78ef690df41dab7.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3704305945_a80e60e2f6_m_jpg.rf.346e935d6087ded0e7b69d4019dc1465.jpg
# /kaggle/input/flowers-dataset/valid/daisy/20685027271_0e7306e7c1_n_jpg.rf.c6edaddb494372b68280ece580982b44.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2480569557_f4e1f0dcb8_n_jpg.rf.be755826d4381afdc14274b2cd6eb299.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3275951182_d27921af97_n_jpg.rf.ecf9875a4abc4446e427d6a6244f785d.jpg
# /kaggle/input/flowers-dataset/valid/daisy/33849854704_d2a2415e4d_n_jpg.rf.2e6aa6660d23383bf92f4d994ffef70e.jpg
# /kaggle/input/flowers-dataset/valid/daisy/14698531521_0c2f0c6539_jpg.rf.787d556676fe7d11fe3909353835a730.jpg
# /kaggle/input/flowers-dataset/valid/daisy/4757448834_a29a9538c9_n_jpg.rf.e62c0bde044bb076fcc6b1ac248bc06b.jpg
# /kaggle/input/flowers-dataset/valid/daisy/33822751084_c83a7abffd_n_jpg.rf.36512eba9e84816a33f70980ff30677e.jpg
# /kaggle/input/flowers-dataset/valid/daisy/7189043225_2fe781439a_n_jpg.rf.2da6438e50d2ad9ffb9c0f9f29ef1626.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34287492780_6dab677857_n_jpg.rf.7be573fe8d8f164db9d0bfdfe7360363.jpg
# /kaggle/input/flowers-dataset/valid/daisy/14330343061_99478302d4_m_jpg.rf.d37aa8b3f0070ec5f4fa6a56af925d60.jpg
# /kaggle/input/flowers-dataset/valid/daisy/9515186037_3be48fe68f_jpg.rf.9aa0250138183eaf3e825ad5c849d86c.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34643914016_2e659d6e82_n_jpg.rf.419ae7d8ee78548041c472e69a58b1a2.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5435522104_1d6a61b431_n_jpg.rf.334199b654fa21082da9d2d1c6fcf473.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34554334542_7d8f68a75c_n_jpg.rf.d676678c93d0bb2ab272ed420186ff26.jpg
# /kaggle/input/flowers-dataset/valid/daisy/25360380_1a881a5648_jpg.rf.35d4a0734686c810ca0d3316bec22568.jpg
# /kaggle/input/flowers-dataset/valid/daisy/10437754174_22ec990b77_m_jpg.rf.56da7cdfbe45bdded2e31374953d470e.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3773181799_5def396456_jpg.rf.8b4126c071f6e652e324988d257f4916.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5896676090_68bb74b1e9_n_jpg.rf.8c6c8c55e8acdfa3ea71054a10f31a5a.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3588872598_e0f9a1d2a1_m_jpg.rf.c1b0ef0dca40c82db1d60e8bc3827661.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2488902131_3417698611_n_jpg.rf.6e0045c4c65d027077fae128391d300f.jpg
# /kaggle/input/flowers-dataset/valid/daisy/4333085242_bbeb3e2841_m_jpg.rf.d56ea33343c57d994533c4c20b46d1d5.jpg
# /kaggle/input/flowers-dataset/valid/daisy/8645839873_0151fb92bf_n_jpg.rf.121e09b945006aba6fb7e0aa5cd9896d.jpg
# /kaggle/input/flowers-dataset/valid/daisy/4598422221_b37313a3e3_n_jpg.rf.22cd3fff9fbe26843b35a11d86a9e7b3.jpg
# /kaggle/input/flowers-dataset/valid/daisy/8382667241_0f046cecdb_n_jpg.rf.132d2a982445bf9c551b3ae847bc3db2.jpg
# /kaggle/input/flowers-dataset/valid/daisy/20619292635_9857a12d54_jpg.rf.2d688447a839d3417507970b1e4a9f7b.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5769217520_c90efc3c93_m_jpg.rf.8e84358d6606a10685aca2f151f88eff.jpg
# /kaggle/input/flowers-dataset/valid/daisy/33901756843_94e198d40e_n_jpg.rf.a9f5024e549e77930ab70a9ff2af0ffd.jpg
# /kaggle/input/flowers-dataset/valid/daisy/8021540573_c56cf9070d_n_jpg.rf.03a6176578ce3f03ec9deb9c9a665885.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5014137563_d03eb0ed75_n_jpg.rf.7ea27c57e20ad37752ad14ea47f9df78.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5110107234_12ddc0206b_m_jpg.rf.a042a83f026cb3e56f95598b0aa0fb87.jpg
# /kaggle/input/flowers-dataset/valid/daisy/8619103877_d8c82c5f34_n_jpg.rf.fb846926ce534f8f10eba4bbffa8beab.jpg
# /kaggle/input/flowers-dataset/valid/daisy/506348009_9ecff8b6ef_jpg.rf.6ee77b8a61afacec4c79d07ecd8824e7.jpg
# /kaggle/input/flowers-dataset/valid/daisy/174131220_c853df1287_jpg.rf.64fd3bdadae8ddf9b65034c2a2fa37cb.jpg
# /kaggle/input/flowers-dataset/valid/daisy/4669117051_ce61e91b76_jpg.rf.378c0b249afbaa64d31c55fb89ce8db8.jpg
# /kaggle/input/flowers-dataset/valid/daisy/695778683_890c46ebac_jpg.rf.002721084494d5922d3f237ea38bf0b5.jpg
# /kaggle/input/flowers-dataset/valid/daisy/15327813273_06cdf42210_jpg.rf.1d82d7702ec0a1577ba9304b56b089c0.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2365428551_39f83f10bf_n_jpg.rf.743a3321a00748058399fc5a3b67ed43.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3084924076_4d5c5711af_m_jpg.rf.8a33bcc64bc3c90c888880949efe6d78.jpg
# /kaggle/input/flowers-dataset/valid/daisy/6210664514_f1d211217a_jpg.rf.f146702e5a13358caa7d6e44ba2d1eea.jpg
# /kaggle/input/flowers-dataset/valid/daisy/14350958832_29bdd3a254_jpg.rf.8334cf8042e62dc55ae0ff146eab9d9e.jpg
# /kaggle/input/flowers-dataset/valid/daisy/15207766_fc2f1d692c_n_jpg.rf.70648115586fcb136c3d337ab75549f1.jpg
# /kaggle/input/flowers-dataset/valid/daisy/437859108_173fb33c98_jpg.rf.d435b1fa04c6ca471d7d511593945037.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3456403987_5bd5fa6ece_n_jpg.rf.9c04ca0620800d5e7771e4b387bfd51e.jpg
# /kaggle/input/flowers-dataset/valid/daisy/9158041313_7a6a102f7a_n_jpg.rf.7c4f87166b327872b939bc83253a25a8.jpg
# /kaggle/input/flowers-dataset/valid/daisy/20580471306_ab5a011b15_n_jpg.rf.f894c158cc68c5e7ffc7009d9d973887.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3410906335_37e8a24b1c_n_jpg.rf.dab0c0a9767e14f61788b21e80794518.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3285641623_da0e47f49a_jpg.rf.0a29b4d881cadd5d44af6a7daf2029fc.jpg
# /kaggle/input/flowers-dataset/valid/daisy/9529916092_de70623523_n_jpg.rf.f8fd8dd41a739e4a63436c2922981525.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3196066025_d187108070_n_jpg.rf.bc73b548c9dcb3f839ed85e149123866.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2561352120_7961d8263f_jpg.rf.0843ed2c6f42b0afa9d98cb4f5ccd23c.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5602738326_97121e007d_n_jpg.rf.4be0e18668dcc69f3dceebb594e5f803.jpg
# /kaggle/input/flowers-dataset/valid/daisy/10712722853_5632165b04_jpg.rf.9478fbc7533f7f282c80e8344e01eb93.jpg
# /kaggle/input/flowers-dataset/valid/daisy/9467543719_c4800becbb_m_jpg.rf.67486a7209e840364fca93ac55660312.jpg
# /kaggle/input/flowers-dataset/valid/daisy/18582579815_4c6637e9ff_m_jpg.rf.ce1e521f5d0d018742cb17bde6feff6f.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5973488341_50bdf6cee3_n_jpg.rf.30d5810e7d1f05d55b25b36fad20e4b4.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3758221664_b19116d61f_jpg.rf.c17fbf11c4387c40d760d86e77ad67f5.jpg
# /kaggle/input/flowers-dataset/valid/daisy/6299910262_336309ffa5_n_jpg.rf.4d977a31a491f73884237c394d6cc927.jpg
# /kaggle/input/flowers-dataset/valid/daisy/11124324295_503f3a0804_jpg.rf.90cbd83dacc888329199a4dbbe09f763.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3117644024_1cbb59a509_n_jpg.rf.920c6a11af61f8f8f30359192584b623.jpg
# /kaggle/input/flowers-dataset/valid/daisy/16291797949_a1b1b7c2bd_n_jpg.rf.dea8f63ec1fc40cd763eac5780f80050.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3720632920_93cf1cc7f3_m_jpg.rf.72efadb681fa6fb9e4fd9310498eb9f8.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34701078235_4a770d14a1_n_jpg.rf.cfd33e5bef4e5ab9662d8e54bbe6a4ce.jpg
# /kaggle/input/flowers-dataset/valid/daisy/6884975451_c74f445d69_m_jpg.rf.c94da1266d715af5418525716203c0bc.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2581171297_b0a249b92b_n_jpg.rf.9acf1bc1a8d4b722e11a922e548e7e8f.jpg
# /kaggle/input/flowers-dataset/valid/daisy/6095817094_3a5b1d793d_jpg.rf.196f7414bc2a735e83b303b63be9148e.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34602180741_cf2f671ba5_n_jpg.rf.f4ebece048b14f13a095680792689200.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2454280135_ac3aa75cdc_n_jpg.rf.887628306390369ec097b003e3f1ce53.jpg
# /kaggle/input/flowers-dataset/valid/daisy/6978826370_7b9aa7c7d5_jpg.rf.11b5f11b09d429b24f9357616af33b83.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3661613900_b15ca1d35d_m_jpg.rf.3f063183919033f72398c7374aa6faa4.jpg
# /kaggle/input/flowers-dataset/valid/daisy/18203367608_07a04e98a4_n_jpg.rf.3e4a609293c2c7dae23fcb7e7bb5844b.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34476770012_38fba290f3_n_jpg.rf.adc5ee16a35c117ad35a52cbf574c461.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34310869690_56cdc84a17_n_jpg.rf.d9f8a84b5b19debfe0168402def5ba6c.jpg
# /kaggle/input/flowers-dataset/valid/daisy/8719756744_34a5a83976_n_jpg.rf.5fe0825d13cddccc4ad15e64c15aaf09.jpg
# /kaggle/input/flowers-dataset/valid/daisy/18023717391_e2c9089e10_jpg.rf.06545eedc5a3dddf9a3e9cd71505663d.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34532930772_5cc5fc600d_n_jpg.rf.67b5930f1415efcc9934cebb13f71567.jpg
# /kaggle/input/flowers-dataset/valid/daisy/162362897_1d21b70621_m_jpg.rf.4bca1a07f884e7c5e21593ff199a645b.jpg
# /kaggle/input/flowers-dataset/valid/daisy/16819071290_471d99e166_m_jpg.rf.fa518ab30276578586959fe5b8c1d0b7.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34510103621_250ee7ae64_n_jpg.rf.638f3e5cf217a25115840c848b52276f.jpg
# /kaggle/input/flowers-dataset/valid/daisy/18354545086_693ea7bc2a_jpg.rf.d23c7564f681f45bc26090f729062b41.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5512287917_9f5d3f0f98_n_jpg.rf.d18982c4943884d52f200de957db7184.jpg
# /kaggle/input/flowers-dataset/valid/daisy/33838292353_8b143f7980_n_jpg.rf.0e11d02227c2c6ddeb49205b6b5d7047.jpg
# /kaggle/input/flowers-dataset/valid/daisy/18195689904_46619b7e16_n_jpg.rf.c3e4317c94918d3eb2543a8d471a90c3.jpg
# /kaggle/input/flowers-dataset/valid/daisy/10437770546_8bb6f7bdd3_m_jpg.rf.539b70c93afeae3554329b43824a5ca4.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34540176411_a35a19a8ef_n_jpg.rf.6197755b8f4433f00aa8e1fe33bb48b1.jpg
# /kaggle/input/flowers-dataset/valid/daisy/28056118836_77a6847d94_n_jpg.rf.b4a90eb36ffca2ef6ec77f477b77ddac.jpg
# /kaggle/input/flowers-dataset/valid/daisy/14554906452_35f066ffe9_n_jpg.rf.9b2032f6e0e8ac6a2c232d6730adb1c1.jpg
# /kaggle/input/flowers-dataset/valid/daisy/8348621545_8f02b82662_n_jpg.rf.2d996b3ea7e2228b264b54106d4b70c6.jpg
# /kaggle/input/flowers-dataset/valid/daisy/4141147800_813f660b47_jpg.rf.f44e05235da78a741c6a054a91097d4c.jpg
# /kaggle/input/flowers-dataset/valid/daisy/6208851904_9d916ebb32_n_jpg.rf.be299a6a7cbeee0deb82c0ff46435994.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34547261352_d39bf4073a_n_jpg.rf.0068e885ecf26475f71e72b1cb8e737e.jpg
# /kaggle/input/flowers-dataset/valid/daisy/4785888250_b661eac225_n_jpg.rf.d8ac88216aa5649ea455a8c48a726913.jpg
# /kaggle/input/flowers-dataset/valid/daisy/154332674_453cea64f4_jpg.rf.6c73e06882f40a242256192b6b0cd797.jpg
# /kaggle/input/flowers-dataset/valid/daisy/11023272144_fce94401f2_m_jpg.rf.7c529c710ef5e561b4065e103e9a597d.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34665595995_13f76d5b60_n_jpg.rf.4c8e4851187b41d282f4fb23ccfd82a2.jpg
# /kaggle/input/flowers-dataset/valid/daisy/4666648087_b10f376f19_jpg.rf.5c1c209295cabd9039ee33a62f4eb23b.jpg
# /kaggle/input/flowers-dataset/valid/daisy/7568630428_8cf0fc16ff_n_jpg.rf.92b1695fd1a527171e6fea69ad4182f7.jpg
# /kaggle/input/flowers-dataset/valid/daisy/19813618946_93818db7aa_m_jpg.rf.04d74810ee1a7ffe39fa67cda82613f6.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34295444880_b4376b3a8b_n_jpg.rf.2e949406a6d96d57a493967d4589cc80.jpg
# /kaggle/input/flowers-dataset/valid/daisy/13977181862_f8237b6b52_jpg.rf.9dc549f8d59504920f736cd222e18e90.jpg
# /kaggle/input/flowers-dataset/valid/daisy/8740807508_0587f5b7b7_jpg.rf.d26cfb5a9f78784b1cb460189bbe5be7.jpg
# /kaggle/input/flowers-dataset/valid/daisy/9595857626_979c45e5bf_n_jpg.rf.f07c4f220d3dfca75bc30d3ab9268885.jpg
# /kaggle/input/flowers-dataset/valid/daisy/10140303196_b88d3d6cec_jpg.rf.ffe380b34f7886e83d843b8c3ec04e8c.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3628485766_4ff937954a_n_jpg.rf.91eab4990c47259adebfe1cc1a818bbf.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5626784099_b36dd3fb11_n_jpg.rf.2de3fdc78ab0e5dfee9241eda03fb202.jpg
# /kaggle/input/flowers-dataset/valid/daisy/33887503434_a2762228f4_n_jpg.rf.d3c82d5692f0282fe05968d4ad1ddeca.jpg
# /kaggle/input/flowers-dataset/valid/daisy/17821980772_35164ae1e8_n_jpg.rf.cbc53ae8847b4da84f638c9ad62d7aa5.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5673551_01d1ea993e_n_jpg.rf.67903e6adc78b5d3de2a898c82911350.jpg
# /kaggle/input/flowers-dataset/valid/daisy/144099102_bf63a41e4f_n_jpg.rf.a8863e53ad302e4c4aacef8347664c73.jpg
# /kaggle/input/flowers-dataset/valid/daisy/8983779970_9d3a6a3bf2_n_jpg.rf.a439044597ae238e7f048e96379c2ade.jpg
# /kaggle/input/flowers-dataset/valid/daisy/2619413565_61a6cd3ac9_m_jpg.rf.4b11b97a03ea6a3a15a248fb44872153.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34590677231_0ed33ccd55_n_jpg.rf.8cae841b80e5d40299277a77a639a074.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5896105367_fa08a65869_n_jpg.rf.f22f182d1f7cdc22c58e23b04339a12d.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3695826945_9f374e8a00_m_jpg.rf.8d311663690947beebf67e198ec9110f.jpg
# /kaggle/input/flowers-dataset/valid/daisy/172882635_4cc7b86731_m_jpg.rf.41433c60b4f982822cfe6197ad5bd20c.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34637970155_a2b917077c_n_jpg.rf.2fc44a9163b39bc444188c9963e94641.jpg
# /kaggle/input/flowers-dataset/valid/daisy/34288158610_6e42406193_n_jpg.rf.ccde85d9f26f8a4d4c143fe5c9c40ea7.jpg
# /kaggle/input/flowers-dataset/valid/daisy/13583238844_573df2de8e_m_jpg.rf.3200e1861773f7e3c93ba079feac1af3.jpg
# /kaggle/input/flowers-dataset/valid/daisy/5087720485_c0914fb623_jpg.rf.6f6380c0fc65881e96929276c88b8ecd.jpg
# /kaggle/input/flowers-dataset/valid/daisy/9496209717_25a6ebdab6_m_jpg.rf.ecac94c472421cc279e0992fc250b8c9.jpg
# /kaggle/input/flowers-dataset/valid/daisy/4753134939_8e87649db6_jpg.rf.31a107a953902a24cc54e4d0336e414e.jpg
# /kaggle/input/flowers-dataset/valid/daisy/3962240986_0661edc43a_n_jpg.rf.486f4f9060644e1656d269d25eae1ba6.jpg
# /kaggle/input/flowers-dataset/valid/daisy/14245834619_153624f836_jpg.rf.f51e28533bb7efee3c3de6d7bb200f23.jpg
# /kaggle/input/flowers-dataset/test/dandelion/4523862714_b41b459c88_jpg.rf.7e35d44b33f191b29aa5c9527f919fd7.jpg
# /kaggle/input/flowers-dataset/test/dandelion/14093789753_f0f1acdb57_jpg.rf.28b44ee77efcb9ac8ae5c33280de9fac.jpg
# /kaggle/input/flowers-dataset/test/dandelion/2401343175_d2a892cf25_n_jpg.rf.8f9bba257cc9d8fafd2ff4da8a173799.jpg
# /kaggle/input/flowers-dataset/test/dandelion/15002906952_cab2cb29cf_jpg.rf.78c84dee8f0d178cb3a5a5f6a41cb3f7.jpg
# /kaggle/input/flowers-dataset/test/dandelion/9472854850_fc9e1db673_jpg.rf.56dff30fc81dda636a82985f8a1927d3.jpg
# /kaggle/input/flowers-dataset/test/dandelion/17220096449_0e535989f0_n_jpg.rf.8db24b20eb779259f9480a46592ab911.jpg
# /kaggle/input/flowers-dataset/test/dandelion/8797114213_103535743c_m_jpg.rf.132646214f7e9bcbdda402ab688ca868.jpg
# /kaggle/input/flowers-dataset/test/dandelion/23414449869_ee849a80d4_jpg.rf.75bc6edba69719ef993bde64f403751a.jpg
# /kaggle/input/flowers-dataset/test/dandelion/11768468623_9399b5111b_n_jpg.rf.2237b890deba7d703e59bf44398efdb1.jpg
# /kaggle/input/flowers-dataset/test/dandelion/8720503800_cab5c62a34_jpg.rf.1d6d4f796a29224232c39a61a0d0b659.jpg
# /kaggle/input/flowers-dataset/test/dandelion/3491333876_e3fed43c0d_jpg.rf.e24ee16e80dbe63c8629959ee6b402b4.jpg
# /kaggle/input/flowers-dataset/test/dandelion/6400843175_ef07053f8f_m_jpg.rf.31fc1a6ef37c85f41af7f93c628e150a.jpg
# /kaggle/input/flowers-dataset/test/dandelion/2478018280_1be353ca8c_m_jpg.rf.13e686968dc86acd0a5922e50bf0c30d.jpg
# /kaggle/input/flowers-dataset/test/dandelion/4489359360_09db62f825_jpg.rf.dd23d2557efa164171ccc721e6f6b275.jpg
# /kaggle/input/flowers-dataset/test/dandelion/13900486390_5a25785645_n_jpg.rf.6ca8083ee0bd606f480c84359984ca19.jpg
# /kaggle/input/flowers-dataset/test/dandelion/14292205986_da230467ef_jpg.rf.41579775e68a4c026e860f6cc0b23fba.jpg
# /kaggle/input/flowers-dataset/test/dandelion/16096748028_7876887ab2_jpg.rf.268b74eb940038b4b12138f59cb68eea.jpg
# /kaggle/input/flowers-dataset/test/dandelion/14376454225_a1de336c5b_jpg.rf.285a4f2bbf8c8ba3e0a20d9bf40af4b5.jpg
# /kaggle/input/flowers-dataset/test/dandelion/34700475225_fbc12d0834_n_jpg.rf.9e2f64d8f6f3f5c0a649fa0ed1022151.jpg
# /kaggle/input/flowers-dataset/test/dandelion/5674707921_1ffd141bab_n_jpg.rf.2596c5cd360fc35c47bc33d7b4e071df.jpg
# /kaggle/input/flowers-dataset/test/dandelion/14060367700_fe87e99b6a_m_jpg.rf.eaf8222cde370b2ebb4d6a1378ec07b1.jpg
# /kaggle/input/flowers-dataset/test/dandelion/34339792440_8224ca420d_n_jpg.rf.28965bc70aeff840d1cbfcb0b1cb0125.jpg
# /kaggle/input/flowers-dataset/test/dandelion/2938040169_eb38581359_jpg.rf.4569e5c84f6eabb13537095f2eca9f3e.jpg
# /kaggle/input/flowers-dataset/test/dandelion/129019877_8eea2978ca_m_jpg.rf.fefbc3553fc43efbc15140a65fff928c.jpg
# /kaggle/input/flowers-dataset/test/dandelion/7280222348_a87725ca77_jpg.rf.78a9c3e6b47349930d5c0ea7320649d4.jpg
# /kaggle/input/flowers-dataset/test/dandelion/3393060921_2328b752f4_jpg.rf.cab8ffcf64f4ddcb03ff73944d3d42d2.jpg
# /kaggle/input/flowers-dataset/test/dandelion/16744522344_8d21b1530d_n_jpg.rf.234876facfaf654db754d97876625ced.jpg
# /kaggle/input/flowers-dataset/test/dandelion/4510938552_6f7bae172a_n_jpg.rf.44e3121f52842ca7b65a91745b892f74.jpg
# /kaggle/input/flowers-dataset/test/dandelion/5129135346_3fa8e804d8_n_jpg.rf.e088200b9397d327366f5ed3b24c75a5.jpg
# /kaggle/input/flowers-dataset/test/dandelion/8757650550_113d7af3bd_jpg.rf.15f92a268cac709e3670303db4a842a2.jpg
# /kaggle/input/flowers-dataset/test/dandelion/5608832856_f5d49de778_jpg.rf.a8dc767f6b06720677e5976be3156a66.jpg
# /kaggle/input/flowers-dataset/test/dandelion/4552591312_02fe1dcc04_n_jpg.rf.ae80a313b268b1aa2d5ac5c380b953df.jpg
# /kaggle/input/flowers-dataset/test/dandelion/16159487_3a6615a565_n_jpg.rf.6d473a1fe680a3e930f3ff28464c46a9.jpg
# /kaggle/input/flowers-dataset/test/dandelion/3688128868_031e7b53e1_n_jpg.rf.10b3b81237b2b346fcfe9bb064efe578.jpg
# /kaggle/input/flowers-dataset/test/dandelion/5996421299_b9bf488c1a_n_jpg.rf.3c0de45f7ae465fa9f87a60211398777.jpg
# /kaggle/input/flowers-dataset/test/dandelion/3585220976_5acac92d1c_jpg.rf.937da2bac5815ba707c9d50da10418a3.jpg
# /kaggle/input/flowers-dataset/test/dandelion/510874382_f7e3435043_jpg.rf.b29f5681a3f5849d65b2efd17365006d.jpg
# /kaggle/input/flowers-dataset/test/dandelion/8376558865_19c5cd6fd6_n_jpg.rf.ba46776fd6d0edac2feae7f2c3724689.jpg
# /kaggle/input/flowers-dataset/test/dandelion/33877161494_05686b7f7a_n_jpg.rf.ed0b5bf52a84350b9492009ec9e5c7c8.jpg
# /kaggle/input/flowers-dataset/test/dandelion/4588529727_4a79c61577_jpg.rf.c364d40053a8642deb3fd410bade1fea.jpg
# /kaggle/input/flowers-dataset/test/dandelion/3513200808_390f1d63a7_m_jpg.rf.73d45d87b1573a6e9bb7f3467e7d2cfc.jpg
# /kaggle/input/flowers-dataset/test/dandelion/3398195641_456872b48b_n_jpg.rf.e265ac40570c8bf38cb832950b9f349e.jpg
# /kaggle/input/flowers-dataset/test/dandelion/1241011700_261ae180ca_jpg.rf.53eafd845f17fbf30ebd87b04312a4e8.jpg
# /kaggle/input/flowers-dataset/test/dandelion/8663932737_0a603ab718_n_jpg.rf.d2d2a30c1e07cd5b7a547c0aad17b090.jpg
# /kaggle/input/flowers-dataset/test/dandelion/34719559905_46ba779d79_n_jpg.rf.68254c0bb5877d9d4e758c3c3c87ab75.jpg
# /kaggle/input/flowers-dataset/test/dandelion/4500964841_b1142b50fb_n_jpg.rf.2f8b5152ea3e62f140937a540a900150.jpg
# /kaggle/input/flowers-dataset/test/dandelion/15139657325_74031c44fc_jpg.rf.803ef4e8fd620413d4344d49d9b3e680.jpg
# /kaggle/input/flowers-dataset/test/dandelion/5628296138_9031791fab_jpg.rf.83bdf72c3a00be6ada06aa67ca56e1db.jpg
# /kaggle/input/flowers-dataset/test/dandelion/141340262_ca2e576490_jpg.rf.a9e7a7e679798619924bbc5cade9f806.jpg
# /kaggle/input/flowers-dataset/test/dandelion/6132275522_ce46b33c33_m_jpg.rf.57b01e9c534a3210f229897712f497d0.jpg
# /kaggle/input/flowers-dataset/test/dandelion/33850973214_c1b4000d9c_n_jpg.rf.3d799530874a6cbce1eb1ae336ec953c.jpg
# /kaggle/input/flowers-dataset/test/dandelion/7197581386_8a51f1bb12_n_jpg.rf.587722330b3a0f634957ca4f1d46f1c3.jpg
# /kaggle/input/flowers-dataset/test/dandelion/4134441089_c8c1e6132a_jpg.rf.edca5d6f4cc4dc7b15488f670eb5b65f.jpg
# /kaggle/input/flowers-dataset/test/dandelion/5033866477_a77cccba49_m_jpg.rf.c957f23b2e995138535b3b0b99eee48c.jpg
# /kaggle/input/flowers-dataset/test/dandelion/3554435478_1a7ab743e9_n_jpg.rf.07d5667ff8bfd641e5004f6b2270d4b6.jpg
# /kaggle/input/flowers-dataset/test/dandelion/7196683612_6c4cf05b24_jpg.rf.2cfae8f98efa6f23b54e8506e81bf1f7.jpg
# /kaggle/input/flowers-dataset/test/dandelion/13471273823_4800ca8eec_jpg.rf.ba3ad39b915d39d0ee59f4a14beefd99.jpg
# /kaggle/input/flowers-dataset/test/dandelion/14053173516_a00150a919_m_jpg.rf.db62016c6ebd3912dcc994dbe53edaee.jpg
# /kaggle/input/flowers-dataset/test/dandelion/18183515403_13a9ca6d86_n_jpg.rf.bd063bad62c4378582b6433f3ce2fcb8.jpg
# /kaggle/input/flowers-dataset/test/dandelion/7243174412_d3628e4cc4_m_jpg.rf.3a171e63d844752eec452386e4362e4f.jpg
# /kaggle/input/flowers-dataset/test/dandelion/13887031789_97437f246b_jpg.rf.bb669fcee9abb45aabf5352790b35ec8.jpg
# /kaggle/input/flowers-dataset/test/dandelion/4151883194_e45505934d_n_jpg.rf.e6d750a2d2fa9c88acc0a4c24e8bb83b.jpg
# /kaggle/input/flowers-dataset/test/dandelion/6983113346_21551e1b52_n_jpg.rf.b3d0cb87aa97f08eb240a27eb0b63dab.jpg
# /kaggle/input/flowers-dataset/test/dandelion/17688233756_21879104c1_n_jpg.rf.2c602dd144b226c6eaec1c52a123a388.jpg
# ...
# /kaggle/input/flowers-dataset/train/daisy/34266044490_01dacd2ac2_n_jpg.rf.7a824cd5b2506057e835e9508c63fe4b.jpg
# /kaggle/input/flowers-dataset/train/daisy/34283602490_b61f3da99d_n_jpg.rf.629395fa4fed45b029f0ccb44d92aeac.jpg
# /kaggle/input/flowers-dataset/train/daisy/3356112863_75da8bca2c_m_jpg.rf.7e503c1bd37ac5d786ec68e33a22b985.jpg
# /kaggle/input/flowers-dataset/train/daisy/34696730346_5f0c131e59_n_jpg.rf.bb00544c60f4b916d5fc02ff656b240a.jpg
# /kaggle/input/flowers-dataset/train/daisy/4746633946_23933c0810_jpg.rf.1abf0d1bcfe4fd1da1674eab90120338.jpg
# /kaggle/input/flowers-dataset/train/daisy/10391248763_1d16681106_n_jpg.rf.9e5d0cdda4652c9179d6696b9ad227f4.jpg
# /kaggle/input/flowers-dataset/train/daisy/3999978867_c67c79597f_m_jpg.rf.1311aea4bc5ae75d57c86a7eb9c31641.jpg
# /kaggle/input/flowers-dataset/train/daisy/525780443_bba812c26a_m_jpg.rf.baf82e6e92bc45e30ca9cc374cdfbd62.jpg
# /kaggle/input/flowers-dataset/train/daisy/19653086178_28156b7ce4_m_jpg.rf.8b0d69ab48d3cb3a706de9096ff69d74.jpg
# /kaggle/input/flowers-dataset/train/daisy/515112668_a49c69455a_jpg.rf.bdc890908b81624f8d17840c51c313d4.jpg
# /kaggle/input/flowers-dataset/train/daisy/34611565966_9de274f987_n_jpg.rf.ea6fb8a8137bb42a5d5b697273c22c31.jpg
# /kaggle/input/flowers-dataset/train/daisy/34326606950_41ff8997d7_n_jpg.rf.964d0ff272780e55c4084e616f5d01f2.jpg
# /kaggle/input/flowers-dataset/train/daisy/14221836990_90374e6b34_jpg.rf.fb884888f97149437a8b478343fc8ce4.jpg
# /kaggle/input/flowers-dataset/train/daisy/4286053334_a75541f20b_m_jpg.rf.ae177708bc722d735f0983a17b789d06.jpg
# /kaggle/input/flowers-dataset/train/daisy/7358085448_b317d11cd5_jpg.rf.7f006bde9cd4ea4ea3e50155ceea56be.jpg
# /kaggle/input/flowers-dataset/train/daisy/9489270024_1b05f08492_m_jpg.rf.58508cfd8f891211e7a507b0eceb260b.jpg
# /kaggle/input/flowers-dataset/train/daisy/10555826524_423eb8bf71_n_jpg.rf.9404443ba752170e09436475263272e4.jpg
# /kaggle/input/flowers-dataset/train/daisy/33858238653_6549e21f53_n_jpg.rf.55bfb455defdbd82427ffad50ea6b6c8.jpg
# /kaggle/input/flowers-dataset/train/daisy/5109508979_68e3530791_m_jpg.rf.b9c5367128f7fdd79dab9f10f26fa5a4.jpg
# /kaggle/input/flowers-dataset/train/daisy/175106495_53ebdef092_n_jpg.rf.3a3dd6d800affde1f5a85cebd9f9441d.jpg
# /kaggle/input/flowers-dataset/train/daisy/14114116486_0bb6649bc1_m_jpg.rf.35e026c587650057f4ea34f00dcc011d.jpg
# /kaggle/input/flowers-dataset/train/daisy/5673728_71b8cb57eb_jpg.rf.301ae6f40c7f9be5732c929b3c77d3b8.jpg
# /kaggle/input/flowers-dataset/train/daisy/3450822975_7e77d67636_n_jpg.rf.793fd026be5fd5a6405b02a42d505faa.jpg
# /kaggle/input/flowers-dataset/train/daisy/1285423653_18926dc2c8_n_jpg.rf.eca7dfdedf39ca97d5fbb073ae8b1215.jpg
# /kaggle/input/flowers-dataset/train/daisy/3780380240_ef9ec1b737_m_jpg.rf.f1c3cd19b257ab79c3b6e3ae6f65aea4.jpg
# /kaggle/input/flowers-dataset/train/daisy/6910811638_aa6f17df23_jpg.rf.f6a34d201f0ad014d707fbfb8784a4b4.jpg
# /kaggle/input/flowers-dataset/train/daisy/20289938802_e16fa9f23d_jpg.rf.51a5026e455b588fdc09b716f9f7ab30.jpg
# /kaggle/input/flowers-dataset/train/daisy/11834945233_a53b7a92ac_m_jpg.rf.e94e6ba3609a925e79d287cfa5cdaf70.jpg
# /kaggle/input/flowers-dataset/train/daisy/5896674046_a4879f718e_n_jpg.rf.3eb106db2ea17eceab580ba8de94815c.jpg
# /kaggle/input/flowers-dataset/train/daisy/17101762155_2577a28395_jpg.rf.7a227e5b1ae66050fd1dbbdfe20466aa.jpg
# /kaggle/input/flowers-dataset/train/daisy/3703643767_dee82cdef9_n_jpg.rf.c001b55364816221e44648204eceae95.jpg
# /kaggle/input/flowers-dataset/train/daisy/5811226952_4650ed70ae_n_jpg.rf.e0469c85076f506fb2f49031baf985d8.jpg
# /kaggle/input/flowers-dataset/train/daisy/14021430525_e06baf93a9_jpg.rf.c0384ca6f02ebf97de6005356ba4def8.jpg
# /kaggle/input/flowers-dataset/train/daisy/10437929963_bc13eebe0c_jpg.rf.0de4cb95609bb00af8d20f7e5a58e956.jpg
# /kaggle/input/flowers-dataset/train/daisy/102841525_bd6628ae3c_jpg.rf.f31e1d31191041b13307dce646253519.jpg
# /kaggle/input/flowers-dataset/train/daisy/1306119996_ab8ae14d72_n_jpg.rf.76f1660ed941f07461dafccbb51a89fa.jpg
# /kaggle/input/flowers-dataset/train/daisy/16401288243_36112bd52f_m_jpg.rf.bdea413fa8577444de7bb8dee5745032.jpg
# /kaggle/input/flowers-dataset/train/daisy/34546994701_a000b283f1_n_jpg.rf.cbac10a12c559515bd43cb635cd45c1c.jpg
# /kaggle/input/flowers-dataset/train/daisy/8887005939_b19e8305ee_jpg.rf.068822bc477e3d5fd2f5fcd8e4419a69.jpg
# /kaggle/input/flowers-dataset/train/daisy/5434913005_409c1e8b56_n_jpg.rf.46bf75074fd25b2dd344172609f0333e.jpg
# /kaggle/input/flowers-dataset/train/daisy/4258408909_b7cc92741c_m_jpg.rf.52884206773fb24b144e735bcc99cd6c.jpg
# /kaggle/input/flowers-dataset/train/daisy/3080880039_4f1bd592e5_n_jpg.rf.601cd0b0e4985a88bf2cb581c9c07173.jpg
# /kaggle/input/flowers-dataset/train/daisy/5881907044_92a85a05c8_n_jpg.rf.37f49c03e6e7c01f5f3c67d7c42d8a44.jpg
# /kaggle/input/flowers-dataset/train/daisy/2498632196_e47a472d5a_jpg.rf.702b9e12ee2e9f0778cb530f5a5baa1d.jpg
# /kaggle/input/flowers-dataset/train/daisy/4318007511_e9f4311936_n_jpg.rf.e1edce2a2cb9f9e5fe0ad0b22283622f.jpg
# /kaggle/input/flowers-dataset/train/daisy/21805938544_bf6bb0e4bc_jpg.rf.d80195964d23775f3cb7e19d2b145b41.jpg
# /kaggle/input/flowers-dataset/train/daisy/23095658544_7226386954_n_jpg.rf.73ca717b5574c0b9aa03529528b1ff8e.jpg
# /kaggle/input/flowers-dataset/train/daisy/2213954589_c7da4b1486_jpg.rf.43c4ac9c14f40729b10c29d6c5c13502.jpg
# /kaggle/input/flowers-dataset/train/daisy/19544831049_0d738d4872_m_jpg.rf.e02f0c12f1bea2a3f0bdd5dc2dc2ddd0.jpg
# /kaggle/input/flowers-dataset/train/daisy/3848258315_ed2fde4fb4_jpg.rf.346de32928e4b03acec7d516b630b969.jpg
# /kaggle/input/flowers-dataset/train/daisy/9054268881_19792c5203_n_jpg.rf.01f095c09f80e48d472c2df615a401ed.jpg
# /kaggle/input/flowers-dataset/train/daisy/422094774_28acc69a8b_n_jpg.rf.8b08cb771679e81231bf9cf758195faf.jpg
# /kaggle/input/flowers-dataset/train/daisy/3326037909_b5ae370722_n_jpg.rf.7779d2ffdb410ac8de7d8e4433e2c653.jpg
# /kaggle/input/flowers-dataset/train/daisy/34696730126_056ffea63c_n_jpg.rf.fafa37a60ead328f39bd9b5e5c53f572.jpg
# /kaggle/input/flowers-dataset/train/daisy/34729724865_787c98299d_n_jpg.rf.0bc876fa938ab579ecb3f9632c9e4e07.jpg
# /kaggle/input/flowers-dataset/train/daisy/2649404904_b7a91991bb_n_jpg.rf.e33d01624457d9a22d01a810b1dbc9b1.jpg
# /kaggle/input/flowers-dataset/train/daisy/3386988684_bc5a66005e_jpg.rf.e534d71d342c21513c82ba0852fc0a51.jpg
# /kaggle/input/flowers-dataset/train/daisy/3611577717_f3a7a8c416_n_jpg.rf.94bd9d24ad934bc3fa392dea281c1016.jpg
# /kaggle/input/flowers-dataset/train/daisy/17357636476_1953c07aa4_n_jpg.rf.3594116374e1caa452187a55d6a9627e.jpg
# /kaggle/input/flowers-dataset/train/daisy/3750250718_eb61146c5f_jpg.rf.6c71eb1ed53470385a59468f747d74da.jpg
# /kaggle/input/flowers-dataset/train/daisy/2408024540_37f0be7cc0_n_jpg.rf.67e01913a9048bcf6057f17f8a07f924.jpg
# /kaggle/input/flowers-dataset/train/daisy/11023214096_b5b39fab08_jpg.rf.fc6eb7797e7c5f0dc7631cf6871a4c57.jpg
# /kaggle/input/flowers-dataset/train/daisy/4085794721_7cd88e0a6c_m_jpg.rf.75a9090affd6204f5a89ea088821b752.jpg
# /kaggle/input/flowers-dataset/train/daisy/16833748795_b681b2839f_n_jpg.rf.f8c2eecdeaf67724849c9d057bdca55c.jpg
# /kaggle/input/flowers-dataset/train/daisy/30001711132_eb0fd7b04c_n_jpg.rf.b9592e369d1f7cf7c6b508b0c9d3f59e.jpg
# /kaggle/input/flowers-dataset/train/daisy/4413849849_b8d2f3bcf1_n_jpg.rf.119dde2109d34f539c3ec08fde73ef92.jpg
# /kaggle/input/flowers-dataset/train/daisy/4724713781_d169f98a35_jpg.rf.b5ab5f44a4dad48752f27f0edf0d2885.jpg
# /kaggle/input/flowers-dataset/train/daisy/3711723108_65247a3170_jpg.rf.eea040bc3fb98c98f827f2b193d72498.jpg
# /kaggle/input/flowers-dataset/train/daisy/9146733107_98b15d3892_m_jpg.rf.c126d99c02ccbfc1a7b73ed4b1c79cb7.jpg
# /kaggle/input/flowers-dataset/train/daisy/29821115270_eccd3866e1_n_jpg.rf.af248ff869caacb7b777f7d83849cd79.jpg
# /kaggle/input/flowers-dataset/train/daisy/3639009391_0f910681b7_jpg.rf.d62965bbcbb95e91fb1749e15f47a4fa.jpg
# /kaggle/input/flowers-dataset/train/daisy/34283646340_4fe48d1bb7_n_jpg.rf.3fec26361f0f5252106c1219f911e3e3.jpg
# /kaggle/input/flowers-dataset/train/daisy/19019544592_b64469bf84_n_jpg.rf.b20e882357ee05475b34144f1d6df3b6.jpg
# /kaggle/input/flowers-dataset/train/daisy/3415180846_d7b5cced14_m_jpg.rf.344f0c8784f5e72a7372c794c8cda085.jpg
# /kaggle/input/flowers-dataset/train/daisy/34718882165_68cdc9def9_n_jpg.rf.e0bb0e73c197194a83a6ef55b497f5fb.jpg
# /kaggle/input/flowers-dataset/train/daisy/9244082319_b1f7e2d8b0_n_jpg.rf.d57012d6e3e4a22a54ba78cd39caa21a.jpg
# /kaggle/input/flowers-dataset/train/daisy/2077865117_9ed85191ae_n_jpg.rf.1768f4455a7060e8197be2520bd348b1.jpg
# /kaggle/input/flowers-dataset/train/daisy/43474673_7bb4465a86_jpg.rf.daac9bc832d16c575f73e340fec68c29.jpg
# /kaggle/input/flowers-dataset/train/daisy/34530932101_957fab3650_n_jpg.rf.3babe64175395d6c289612b743ac1315.jpg
# /kaggle/input/flowers-dataset/train/daisy/34693373736_9ce6d9e1c3_n_jpg.rf.b2814ec0b1778f5a1e2d129a914dd1d7.jpg
# /kaggle/input/flowers-dataset/train/daisy/9310226774_d1b8f5d9c9_jpg.rf.8e7b3a9d579162355759233d2c74e22c.jpg
# /kaggle/input/flowers-dataset/train/daisy/9120905231_329598304e_jpg.rf.5c44962e1eb7ddab88e89b2d0518e188.jpg
# /kaggle/input/flowers-dataset/train/daisy/176375506_201859bb92_m_jpg.rf.26a158e9518ae911b2e2a99d211f10d0.jpg
# /kaggle/input/flowers-dataset/train/daisy/19178753159_a471bf4b6b_jpg.rf.53ceba39c0132e88754cdd4a9e74ac90.jpg
# /kaggle/input/flowers-dataset/train/daisy/33890808514_ca21f75499_n_jpg.rf.0eea5817f2ef705928c094c57bb50471.jpg
# /kaggle/input/flowers-dataset/train/daisy/3711892138_b8c953fdc1_z_jpg.rf.401c0abf6ff011534f3d780353b09699.jpg
# /kaggle/input/flowers-dataset/train/daisy/5665838969_fe217988b9_m_jpg.rf.0232b8170fd6e168c342bf5d0926d792.jpg
# /kaggle/input/flowers-dataset/train/daisy/4229503616_9b8a42123c_n_jpg.rf.29de957f95348e47b609e9a9c00b35ea.jpg
# /kaggle/input/flowers-dataset/train/daisy/16527403771_2391f137c4_n_jpg.rf.995cc10c1664df88dccbbdb1b913f9df.jpg
# /kaggle/input/flowers-dataset/train/daisy/2473825306_62fd5f8785_n_jpg.rf.67a4e9c30c0e7f3b519dcbf04ad5ec52.jpg
# /kaggle/input/flowers-dataset/train/daisy/34337108550_0b619aa726_n_jpg.rf.567c87bdca01fcd04d4123412a1f324c.jpg
# /kaggle/input/flowers-dataset/train/daisy/5632774792_0fa33d17eb_n_jpg.rf.1b122d0910f46a39914f69d55bbe1919.jpg
# /kaggle/input/flowers-dataset/train/daisy/9161647994_e39b65cb9c_n_jpg.rf.32b8fa05cbf4bafcc4d33279920264a3.jpg
# /kaggle/input/flowers-dataset/train/daisy/34540113401_b81594e92a_n_jpg.rf.d76884d2c83da4c2bf248ba35ed6eb63.jpg
# /kaggle/input/flowers-dataset/train/daisy/799952628_bf836677fa_n_jpg.rf.18738a8ffb18da33f95fbe32594faf59.jpg
# /kaggle/input/flowers-dataset/train/daisy/18400014056_2e4c601ed5_jpg.rf.596753450bfaff8caac8e01b160e9339.jpg
# /kaggle/input/flowers-dataset/train/daisy/14523675369_97c31d0b5b_jpg.rf.9881161f48b225f69907318a9cbfe3a3.jpg
# /kaggle/input/flowers-dataset/train/daisy/8709110478_60d12efcd4_n_jpg.rf.e9f6d7f728cbb024b3f9043ac9f7bffd.jpg
# /kaggle/input/flowers-dataset/train/daisy/4065883015_4bb6010cb7_n_jpg.rf.f5c4c735ac6e501f206c79255ffe23a0.jpg
# /kaggle/input/flowers-dataset/train/daisy/521762040_f26f2e08dd_jpg.rf.771ec23dfdc6b1e043cf498fe877d2c4.jpg
# /kaggle/input/flowers-dataset/train/daisy/4727955343_0bb23ac4ae_jpg.rf.a3838f88e5b85fac4d9317e9cf66dc6a.jpg
# /kaggle/input/flowers-dataset/train/daisy/5110105726_53eb7a93be_m_jpg.rf.ed8a976a6b06418888d564d55ff7a181.jpg
# /kaggle/input/flowers-dataset/train/daisy/2901376034_cdb4bac26b_m_jpg.rf.0a8a1428bd51b2d10049c05cf09c96be.jpg
# /kaggle/input/flowers-dataset/train/daisy/34613530216_26cf037012_n_jpg.rf.634c9f72a60906df905cb58baec1bd53.jpg
# /kaggle/input/flowers-dataset/train/daisy/7669550908_bc5a11276f_n_jpg.rf.9999dc8077db70c11cc79611aad257c3.jpg
# /kaggle/input/flowers-dataset/train/daisy/34518374242_310e7abd54_n_jpg.rf.255190f711d0946c869c0f5e575db57d.jpg
# /kaggle/input/flowers-dataset/train/daisy/16161045294_70c76ce846_n_jpg.rf.9ab9b981ac1444c433d1cc583f02353a.jpg
# /kaggle/input/flowers-dataset/train/daisy/5434901893_4550be3f84_m_jpg.rf.12a6eb34b00b372b7cea95cd522db067.jpg
# /kaggle/input/flowers-dataset/train/daisy/34326847400_f4de801005_n_jpg.rf.e9aa31fd7841ef3680f4430d7919d49c.jpg
# /kaggle/input/flowers-dataset/train/daisy/4581199679_867652c3f1_n_jpg.rf.c0cbc79001ee60c7a6e015272fc0aea6.jpg
# /kaggle/input/flowers-dataset/train/daisy/144603918_b9de002f60_m_jpg.rf.357e8473872f3f6a7b226d90eb699067.jpg
# /kaggle/input/flowers-dataset/train/daisy/5896675418_e6ff20a739_n_jpg.rf.6ec8a1d4f90c274ed8f22d51ae42233f.jpg
# /kaggle/input/flowers-dataset/train/daisy/2641979584_2b21c3fe29_m_jpg.rf.f6549e044d633e8af600156903bf5960.jpg
# /kaggle/input/flowers-dataset/train/daisy/8694909523_3ca25d449d_n_jpg.rf.c49095c8f5e31e39a18cd0b039df993d.jpg
# /kaggle/input/flowers-dataset/train/daisy/8008258043_5457dd254b_n_jpg.rf.50758e628dcf50c7709211c9bec20c7d.jpg
# /kaggle/input/flowers-dataset/train/daisy/19527362416_8bdcbefb8b_n_jpg.rf.e2e3cb080b183a84707ad9ffa0dddba4.jpg
# /kaggle/input/flowers-dataset/train/daisy/2607132536_d95198e619_n_jpg.rf.2b849275774883f0f23eba97f8eb24a0.jpg
# /kaggle/input/flowers-dataset/train/daisy/33802431204_7c58f4e21b_n_jpg.rf.a4eb75a8b903d233210f1d79745a5fff.jpg
# /kaggle/input/flowers-dataset/train/daisy/5905502226_bb23bd8fa0_n_jpg.rf.8614958933a796772a6e9457b22c8af4.jpg
# /kaggle/input/flowers-dataset/train/daisy/34661399476_9ea7e2fd53_n_jpg.rf.028428b56df5c7c9da2fd5956e9d8e5a.jpg
# /kaggle/input/flowers-dataset/train/daisy/4697206799_19dd2a3193_m_jpg.rf.91eda7125175f1ef5dde1be31464d56d.jpg
# /kaggle/input/flowers-dataset/train/daisy/7702332000_3f21ef4571_n_jpg.rf.938ac8ed1d43f09d9566cdd327339ddc.jpg
# /kaggle/input/flowers-dataset/train/daisy/2479956481_8d1a9699be_n_jpg.rf.a46c4077de19e70b4e0d7b64e20c6638.jpg
# /kaggle/input/flowers-dataset/train/daisy/2346726545_2ebce2b2a6_jpg.rf.acd77002250b699065d76e0dbcc5a272.jpg
# /kaggle/input/flowers-dataset/train/daisy/4440480869_632ce6aff3_n_jpg.rf.678653a6770232f9eb936b11750cae0d.jpg
# /kaggle/input/flowers-dataset/train/daisy/2536529152_33ef3ee078_n_jpg.rf.68fef1480f098486f4224498be82e3ee.jpg
# /kaggle/input/flowers-dataset/train/daisy/34520699571_f880744f46_n_jpg.rf.a4f2591b004fff56e156e75f12d6b643.jpg
# /kaggle/input/flowers-dataset/train/daisy/1299501272_59d9da5510_n_jpg.rf.8d7ab330c3ee08f67d7b3d5cc72996bb.jpg
# /kaggle/input/flowers-dataset/train/daisy/33839388103_79cb79f7bc_n_jpg.rf.dddc0079a713d2fd61ee9893b8e61975.jpg
# /kaggle/input/flowers-dataset/train/daisy/18474740346_ffdaa18032_jpg.rf.c5d287ca5efaa7285f7f03a88798897b.jpg
# /kaggle/input/flowers-dataset/train/daisy/8405273313_bef13f6c27_n_jpg.rf.d300310528fa1eb9cbdf3f3ee8389208.jpg
# /kaggle/input/flowers-dataset/train/daisy/33871813063_d7b6bedafe_n_jpg.rf.715b87e8592ca49c15b666eb3cd89742.jpg
# /kaggle/input/flowers-dataset/train/daisy/4538877108_3c793f7987_m_jpg.rf.d528899ca693ff249473da695e6e321b.jpg
# /kaggle/input/flowers-dataset/train/daisy/4890424315_6a59696357_n_jpg.rf.41017856f189333d58e24d747cf378cf.jpg
# /kaggle/input/flowers-dataset/train/daisy/7288989324_c25d9febbf_jpg.rf.d24b3b85257e1affaa26dd9fd37a1f40.jpg
# /kaggle/input/flowers-dataset/train/daisy/3625257860_33efeef614_m_jpg.rf.0db857f7a815edb682d6cabf506098f9.jpg
# /kaggle/input/flowers-dataset/train/daisy/34485028892_fc238ddfc8_n_jpg.rf.0719f1396ab80d6a5bf9999ddf865b52.jpg
# /kaggle/input/flowers-dataset/train/daisy/435283392_72e4c5b5d6_m_jpg.rf.9eea224eba2f3d6d904585624dfe3f24.jpg
# /kaggle/input/flowers-dataset/train/daisy/7790614422_4557928ab9_n_jpg.rf.df27f3220a21176b20f3eede474a7a7a.jpg
# /kaggle/input/flowers-dataset/train/daisy/34520690871_8fe693bc71_n_jpg.rf.5405dbb3cd3dc45f6febc7c9c8ddb67f.jpg
# /kaggle/input/flowers-dataset/train/daisy/5459481183_18d2d49e44_m_jpg.rf.b3f0fabd8cca63c191299d4d78b82dc7.jpg
# /kaggle/input/flowers-dataset/train/daisy/12701063955_4840594ea6_n_jpg.rf.058be03c02d95624d8c201fe3eedb333.jpg
# /kaggle/input/flowers-dataset/train/daisy/3483303007_42e3f90da7_jpg.rf.53b0fb57d8eeddef588a1b83ef179cce.jpg
# /kaggle/input/flowers-dataset/train/daisy/5773652803_574b51414f_n_jpg.rf.6b84f14f2c6506761e5d60a8fd70c79f.jpg
# /kaggle/input/flowers-dataset/train/daisy/7633425046_8293e3d0e9_m_jpg.rf.b35fc1c1726297d15dc3503a4f7e6208.jpg

# %% [markdown]
# # Model Finder

# %%
avail_pretrained_models = timm.list_models('*davit*',pretrained=True)
print(len(avail_pretrained_models))
avail_pretrained_models

# %% [markdown]
# # Mounting the dataset (Daisy -Danderlion)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("alsaniipe/flowers-dataset")

print("Path to dataset files:", path)

# %% [markdown]
# # Importing the Libraries

# %%
# Cell 1: Imports & Setup
import os
import random
import numpy as np
from collections import Counter
from sklearn.utils.class_weight import compute_class_weight

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import timm
from timm.data import resolve_model_data_config

from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import torch.multiprocessing as mp

# To Avoid any warnings 
warnings.filterwarnings("ignore", category=UserWarning)

#mp.set_start_method('forkserver', force=True)
mp.set_start_method('spawn', force=True)

# Checking the Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # Config and Hyper Parameters

# %%
# Cell 2: Configuration

CFG = {
    # reproducibility
    'seed':            42,

    # data paths
    'train_directory':       '/kaggle/input/flowers-dataset/train',
    'val_directory':         '/kaggle/input/flowers-dataset/valid',
    'test_directory':        '/kaggle/input/flowers-dataset/test',
    'batch_size':      32,
    'num_workers':     2,

    # model
    'model_name':      'davit_base.msft_in1k',

    # training
    'num_epochs':      15,
    'learning_rate':   1e-3,
    'step_size':       7,
    'scheduler_gamma': 0.1,

    # optimizer: 'Adam', 'AdamW', 'SGD'
    'optimizer_name':  'AdamW',
    'weight_decay':    0.0,
    'sgd_momentum':    0.9,

    # loss: 'cross_entropy', 'focal'
    'loss_fn':         'cross_entropy',
    'focal_alpha':     0.25,
    'focal_gamma':     2.0,

    # outputs
    'save_path':       './models',
    'results_dir':     './results'
}

os.makedirs(CFG['save_path'],   exist_ok=True)
os.makedirs(CFG['results_dir'], exist_ok=True)

# %% [markdown]
# # Defining Seed

# %%
# Cell 3: Seed Everything
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(CFG['seed'])

# %% [markdown]
# # Checking Model Config

# %%
data_config = resolve_model_data_config(CFG['model_name'])
print("\n",data_config)

print("Section runs successfully")
# Out:
#  {'input_size': (3, 224, 224), 'interpolation': 'bicubic', 'mean': (0.485, 0.456, 0.406), 'std': (0.229, 0.224, 0.225), 'crop_pct': 0.875, 'crop_mode': 'center'}
# Section runs successfully

# %% [markdown]
# # Model Calling and Datatransforms

# %%
# Cell 4: Helpers—Model & Transforms
def get_model(model_name, num_classes, device=device):
    model = timm.create_model(model_name, pretrained=True, num_classes=num_classes)
    return model.to(device)



# Necessary Data Transforms



def get_data_transforms(model_name, is_training=False):
    # instantiate & derive config, then discard
    temp_model = timm.create_model(model_name, pretrained=True)
    cfg = resolve_model_data_config(temp_model)
    input_size = cfg.get('input_size', (3,224,224))[1:]
    mean       = cfg.get('mean',       (0.485,0.456,0.406))
    std        = cfg.get('std',        (0.229,0.224,0.225))
    del temp_model

    print(f"\n[INFO] Creating {'train' if is_training else 'val/test'} transforms")
    print(f"[INFO] Input size={input_size}, mean={mean}, std={std}")

    transform_list = []
    if is_training:
        transform_list += [
            transforms.RandomResizedCrop(input_size),
            transforms.RandomHorizontalFlip(),
            transforms.RandAugment(num_ops=2, magnitude=9)
        ]
    else:
        transform_list += [
            transforms.Resize([int(x/0.95) for x in input_size]),
            transforms.CenterCrop(input_size)
        ]
    transform_list += [
        transforms.ToTensor(),
        transforms.Normalize(mean=mean, std=std)
    ]
    return transforms.Compose(transform_list)

# %% [markdown]
# # Data Loaders with Reproduicibility

# %%
# Cell 5: DataLoaders with Reproducibility
def seed_worker(worker_id):
    """
    Called on each dataloader worker to ensure its RNG is seeded
    deterministically from the master seed.
    """
    worker_seed = CFG['seed'] + worker_id
    np.random.seed(worker_seed)
    random.seed(worker_seed)


# Dataloaders
def get_dataloaders():
    # 1) Prepare transforms
    train_tf = get_data_transforms(CFG['model_name'], is_training=True)
    val_tf   = get_data_transforms(CFG['model_name'], is_training=False)

    # 2) Build datasets
    train_dataset       = datasets.ImageFolder(CFG['train_directory'], transform=train_tf)
    vaidation_dataset   = datasets.ImageFolder(CFG['val_directory'],   transform=val_tf)
    test_dataset        = datasets.ImageFolder(CFG['test_directory'],  transform=val_tf)

    # 3) Create a fixed‐seed generator for shuffling
    g = torch.Generator()
    g.manual_seed(CFG['seed'])

    # 4) DataLoaders with seeded workers
    train_loader = DataLoader(train_dataset,batch_size=CFG['batch_size'],shuffle=True,num_workers=CFG['num_workers'],pin_memory=True,generator=g)
        #worker_init_fn=seed_worker,
    
    val_loader   = DataLoader(vaidation_dataset,batch_size=CFG['batch_size'],shuffle=False,num_workers=CFG['num_workers'],pin_memory=True)

    
    test_loader  = DataLoader(test_dataset,batch_size=CFG['batch_size'],shuffle=False,num_workers=CFG['num_workers'],pin_memory=True)
        #worker_init_fn=seed_worker

    return train_loader, val_loader, test_loader, train_dataset.classes


# def load_model(model_name, num_classes, epoch, path):
#     model = get_model(model_name, num_classes, device)
#     fn    = os.path.join(path, f"{model_name}_epoch_{epoch}.pth")
#     model.load_state_dict(torch.load(fn, map_location=device))
#     return model

# %% [markdown]
# # Compute Class Weights

# %%
# Cell 6: Compute & Print Class Counts + Weights
train_loader, val_loader, test_loader, class_names = get_dataloaders()
num_classes = len(class_names)

counts    = Counter(train_loader.dataset.targets)
weights_np= compute_class_weight(class_weight='balanced',classes=np.arange(num_classes),y=train_loader.dataset.targets)

class_weights = torch.tensor(weights_np, dtype=torch.float32).to(device)

print(f"\n{'Idx':>3s}  {'Class':<20s}  {'#Samples':>8s}  {'Weight':>8s}")
print("-"*45)
#print("\n")
for idx, name in enumerate(class_names):
    print(f"{idx:3d}  {name:<20s}  {counts[idx]:8d}  {class_weights[idx]:8.4f}")
# Out:
# model.safetensors:   0%|          | 0.00/352M [00:00<?, ?B/s]
# [INFO] Creating train transforms
# [INFO] Input size=(224, 224), mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
#
# [INFO] Creating val/test transforms
# [INFO] Input size=(224, 224), mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
#
# Idx  Class                 #Samples    Weight
# ---------------------------------------------
#   0  daisy                      529    1.2051
#   1  dandelion                  746    0.8546

# %% [markdown]
# # Focal Loss Definition and Optimizers

# %%
# Cell 7: FocalLoss, Criterion & Optimizer Factories
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2.0, weight=None, reduction='mean'):
        super().__init__()
        self.alpha, self.gamma = alpha, gamma
        self.weight, self.reduction = weight, reduction

    def forward(self, logits, targets):
        logpt = F.log_softmax(logits, dim=1)
        pt    = torch.exp(logpt)
        logpt = logpt.gather(1, targets.unsqueeze(1)).view(-1)
        pt    = pt.gather(1, targets.unsqueeze(1)).view(-1)
        mod   = (1 - pt) ** self.gamma
        loss  = -self.alpha * mod * logpt
        if self.weight is not None:
            at   = self.weight.gather(0, targets)
            loss = loss * at
        return loss.mean() if self.reduction=='mean' else loss.sum()

def make_criterion():
    if CFG['loss_fn']=='cross_entropy':
        return nn.CrossEntropyLoss(weight=class_weights)
    elif CFG['loss_fn']=='focal':
        return FocalLoss(alpha=CFG['focal_alpha'], gamma=CFG['focal_gamma'], weight=class_weights)
    else:
        raise ValueError(CFG['loss_fn'])

def make_optimizer(model):
    opt = CFG['optimizer_name'].lower()
    if opt=='adam':
        return optim.Adam(model.parameters(), lr=CFG['learning_rate'], weight_decay=CFG['weight_decay'])
    if opt=='adamw':
        return optim.AdamW(model.parameters(), lr=CFG['learning_rate'], weight_decay=CFG['weight_decay'])
    if opt=='sgd':
        return optim.SGD(model.parameters(), lr=CFG['learning_rate'],momentum=CFG['sgd_momentum'],weight_decay=CFG['weight_decay'])
    raise ValueError(CFG['optimizer_name'])

# %% [markdown]
# # Plotting Metrices and Confusion Matrix and Classification Report

# %%
def plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = list(range(1, len(train_losses) + 1))

    # Loss Plot
    plt.figure()
    plt.plot(epochs, train_losses, 'bo-', label='Train Loss')  # blue circle markers
    plt.plot(epochs, val_losses, 'rs-', label='Val Loss')      # red square markers
    plt.xticks(epochs)  # Force integer ticks on x-axis
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.savefig(os.path.join(CFG['results_dir'], f"loss_curve_{CFG['model_name']}.png"))
    plt.show()
    plt.close()

    # Accuracy Plot
    plt.figure()
    plt.plot(epochs, train_accuracies, 'g^-', label='Train Acc')  # green triangle markers
    plt.plot(epochs, val_accuracies, 'md-', label='Val Acc')      # magenta diamond markers
    plt.xticks(epochs)  # Force integer ticks on x-axis
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()
    plt.savefig(os.path.join(CFG['results_dir'], f"accuracy_curve_{CFG['model_name']}.png"))
    plt.show()
    plt.close()



print("Section runs successfully")
# Out:
# Section runs successfully

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import warnings  # Just use warnings
from sklearn.metrics import classification_report

# Ignore UndefinedMetricWarning
#warnings.filterwarnings("ignore", category=UserWarning)  # Filter UserWarnings in general

# def plot_confusion_matrix(conf_matrix, class_names, model_name, save_dir='./results'):
#     plt.figure(figsize=(8, 6))
#     sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
#                 xticklabels=class_names, yticklabels=class_names)
#     plt.xlabel('Predicted')
#     plt.ylabel('True')
#     plt.title('Confusion Matrix')
    
#     # Save figure
#     os.makedirs(save_dir, exist_ok=True)
#     save_path = os.path.join(save_dir, f"confusion_matrix_{model_name}.png")
#     plt.savefig(save_path)
#     print(f"Confusion matrix saved to: {save_path}")
    
#     plt.show()
#     plt.close()


def plot_confusion_matrix(conf_matrix, class_names, model_name, save_dir='./results'):
    n = len(class_names)
    # scale factors (you can tweak these)
    width_per_class  = 0.6
    height_per_class = 0.6
    min_width, min_height = 8, 6

    fig_width  = max(min_width,  n * width_per_class)
    fig_height = max(min_height, n * height_per_class)

    plt.figure(figsize=(fig_width, fig_height))
    
    sns.heatmap(conf_matrix,annot=True,fmt='d',cmap='Blues',xticklabels=class_names,yticklabels=class_names)

    # rotate x‐ticks if many classes
    if n > 10:
        plt.xticks(rotation=45, ha='right')
    else:
        plt.xticks(rotation=0)
    plt.yticks(rotation=0)

    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    # Save figure
    os.makedirs(save_dir, exist_ok=True)
    save_path = os.path.join(save_dir, f"confusion_matrix_{model_name}.png")
    plt.savefig(save_path, bbox_inches='tight')
    print(f"Confusion matrix saved to: {save_path}")

    plt.show()
    plt.close()



def evaluate_and_save(model, dataloader, class_names, save_dir):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    all_preds = []
    all_labels = []
   
    model.to(device)

    with torch.no_grad():
        for imgs, labels in dataloader:
            imgs, labels = imgs.to(device), labels.to(device)
            outputs = model(imgs)
            preds = torch.argmax(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Metrics
    acc = accuracy_score(all_labels, all_preds)
    
    # Using zero_division=1 to handle undefined metrics
    report = classification_report(all_labels, all_preds, target_names=class_names, output_dict=True, zero_division=1)

    conf_matrix = confusion_matrix(all_labels, all_preds)

    print(f"\n Test Accuracy: {acc:.4f}\n")
    print("Classification Report:\n", classification_report(all_labels, all_preds, target_names=class_names))
    print("Confusion Matrix:\n", conf_matrix)

    # Plot Confusion Matrix
    plot_confusion_matrix(conf_matrix, class_names, CFG['model_name'], save_dir)


    # Save to Excel
    os.makedirs(save_dir, exist_ok=True)
    report_df = pd.DataFrame(report).transpose()
    conf_df = pd.DataFrame(conf_matrix, index=class_names, columns=class_names)

    with pd.ExcelWriter(f"{save_dir}/Test_Metrics_{CFG['model_name']}.xlsx") as writer:
        report_df.to_excel(writer, sheet_name='Classification_Report')
        conf_df.to_excel(writer, sheet_name='Confusion_Matrix')

    print(f"\nResults saved to: {save_dir}/test_metrics.xlsx")

    return acc, report_df, conf_df
    

print("Section runs successfully")
# Out:
# Section runs successfully

# %% [markdown]
# # Main Training Loop and Checkpointing

# %%
# # Cell 9: Main Training Loop + Best‐only Checkpointing
# def run_training():
#     tr_loader, vl_loader, ts_loader, class_names = get_dataloaders()

#     model     = get_model(CFG['model_name'], len(class_names), device)
#     criterion = make_criterion()
#     optimizer = make_optimizer(model)
#     scheduler = lr_scheduler.StepLR(
#         optimizer,
#         step_size=CFG['step_size'],
#         gamma=CFG['scheduler_gamma']
#     )

#     history = {'t_loss':[], 't_acc':[], 'v_loss':[], 'v_acc':[]}
#     best_val_loss = float('inf')
#     best_val_acc  = 0.0

#     for ep in range(1, CFG['num_epochs']+1):
#         # — Train —
#         model.train()
#         tloss = tcorrect = ttotal = 0
#         for x,y in tqdm(tr_loader, desc=f"Epoch {ep} Train", leave=False):
#             x,y = x.to(device), y.to(device)
#             optimizer.zero_grad()
#             out  = model(x)
#             loss = criterion(out, y)
#             loss.backward()
#             optimizer.step()

#             tloss    += loss.item() * x.size(0)
#             tcorrect+= (out.argmax(1)==y).sum().item()
#             ttotal  += y.size(0)
#         tr_loss, tr_acc = tloss/ttotal, tcorrect/ttotal

#         # — Validate —
#         model.eval()
#         vloss = vcorrect = vtotal = 0
#         with torch.no_grad():
#             for x,y in tqdm(vl_loader, desc=f"Epoch {ep} Val", leave=False):
#                 x,y = x.to(device), y.to(device)
#                 out  = model(x)
#                 loss = criterion(out, y)
#                 vloss    += loss.item() * x.size(0)
#                 vcorrect+= (out.argmax(1)==y).sum().item()
#                 vtotal  += y.size(0)
#         val_loss, val_acc = vloss/vtotal, vcorrect/vtotal

#         # step LR
#         scheduler.step()

#         # record history
#         history['t_loss'].append(tr_loss)
#         history['t_acc'].append(tr_acc)
#         history['v_loss'].append(val_loss)
#         history['v_acc'].append(val_acc)

#         print(f"Ep{ep}: tr_loss {tr_loss:.4f}, tr_acc {tr_acc:.4f} | "
#               f"val_loss {val_loss:.4f}, val_acc {val_acc:.4f}")

#         # — Check for new best val_loss —
#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             path = os.path.join(
#                 CFG['save_path'],
#                 f"{CFG['model_name']}_best_val_loss.pth"
#             )
#             torch.save(model.state_dict(), path)
#             print(f"  ↓ New best val_loss ({best_val_loss:.4f}), saved to {path}")

#         # — Check for new best val_acc —
#         if val_acc > best_val_acc:
#             best_val_acc = val_acc
#             path = os.path.join(
#                 CFG['save_path'],
#                 f"{CFG['model_name']}_best_val_acc.pth"
#             )
#             torch.save(model.state_dict(), path)
#             print(f"  ↑ New best val_acc ({best_val_acc:.4f}), saved to {path}")

#     print(f"\nTraining complete. Best val_loss: {best_val_loss:.4f}, Best val_acc: {best_val_acc:.4f}")
#     plot_metrics(history['t_loss'], history['v_loss'], history['t_acc'], history['v_acc'])
#     return history

# # run training
# history = run_training()


# Cell 9: Main Training Loop + Best‐only Checkpointing + LR Printout
def run_training():
    train_loader, validation_loader, test_loader, class_names = get_dataloaders()

    print(f"\n 🚀 Model Name: {CFG['model_name']}\n"
          f"Total Class: {len(class_names)}\n"
          f"Optimizer Used: {CFG['optimizer_name']}\n"
          f"Initial Learning Rate:{CFG['learning_rate']}\n"
          f"Batch Size: {CFG['batch_size']}\n"
          f"Loss Function Used: {CFG['loss_fn']}\n")

    best_validation_loss_epoch_num =0
    best_validation_accuracy_epoch_num=0

    model     = get_model(CFG['model_name'], len(class_names), device)
    
    criterion = make_criterion()
    
    optimizer = make_optimizer(model)
    
    scheduler = lr_scheduler.StepLR(optimizer,step_size=CFG['step_size'],gamma=CFG['scheduler_gamma'])
    

    history = {'Training_Loss':[], 'Training_Accuracy':[], 'Validation_Loss':[], 'Validation_Accuracy':[], 'lr':[]}
    best_val_loss = float('inf')
    best_val_acc  = 0.0

    for ep in range(1, CFG['num_epochs']+1):
        # — Get & record current LR —
        current_lr = optimizer.param_groups[0]['lr']
        
        history['lr'].append(current_lr)

        # — Train —
        model.train()
        tloss = tcorrect = ttotal = 0
        for x,y in tqdm(train_loader, desc=f"Epoch {ep}/{CFG['num_epochs']} Train", leave=False):
            x,y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out  = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

            tloss    += loss.item() * x.size(0)
            tcorrect+= (out.argmax(1)==y).sum().item()
            ttotal  += y.size(0)
        tr_loss, tr_acc = tloss/ttotal, tcorrect/ttotal

        # — Validate —
        model.eval()
        vloss = vcorrect = vtotal = 0
        with torch.no_grad():
            for x,y in tqdm(validation_loader, desc=f"Epoch {ep}/{CFG['num_epochs']} Validation", leave=False):
                x,y = x.to(device), y.to(device)
                out  = model(x)
                loss = criterion(out, y)
                vloss    += loss.item() * x.size(0)
                vcorrect+= (out.argmax(1)==y).sum().item()
                vtotal  += y.size(0)
        val_loss, val_acc = vloss/vtotal, vcorrect/vtotal

        # — Step LR scheduler for next epoch —
        scheduler.step()

        # — Record history —
        history['Training_Loss'].append(tr_loss)
        history['Training_Accuracy'].append(tr_acc)
        history['Validation_Loss'].append(val_loss)
        history['Validation_Accuracy'].append(val_acc)
        #history['Learning Rate'].append(current_lr)

        # — Print stats including LR —
        print(
            f"\n ✅ Epoch Number:{ep}: Learning Rate: {current_lr:.6f} | \n"
            f"   📉 Training_loss {tr_loss:.4f}, Training_Accuracy {tr_acc:.4f} | \n"
            f"   📈Validation_loss {val_loss:.4f}, Validation_Accuracy {val_acc:.4f}\n"
        )

        # — Save if best val_loss —
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_validation_loss_epoch_num=ep
            path = os.path.join(
                CFG['save_path'],
                f"{CFG['model_name']}_best_val_loss.pth"
            )
            torch.save(model.state_dict(), path)
            print(f"  ↓ 🏆 New best val_loss ({best_val_loss:.4f}), saved to {path}")

        # — Save if best val_acc —
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_validation_accuracy_epoch_num=ep
            path = os.path.join(
                CFG['save_path'],
                f"{CFG['model_name']}_best_val_acc.pth"
            )
            torch.save(model.state_dict(), path)
            print(f"  ↑ 🔥 New best val_acc ({best_val_acc:.4f}), saved to {path}")

    metrics_df =pd.DataFrame({
            'Epochs': list(range(1, CFG['num_epochs']+1)),
            'Train Loss': history['Training_Loss'],
            'Validation Loss': history['Validation_Loss'],
            'Training Accuracy': history['Training_Accuracy'],
            'Validation Accuracy': history['Validation_Accuracy']
        })
        
    print(
        f"\nTraining complete. \n"
        f"Best Validation_loss: {best_val_loss:.4f}, \n"
        f"Best Validation Loss Epoch Number: {best_validation_loss_epoch_num}\n"
        f"Best Validatio_Accuracy: {best_val_acc:.4f}\n"
        f"Best Validation Accuracy Epoch Number:{best_validation_accuracy_epoch_num}\n"
    )
    log_path = os.path.join(CFG['results_dir'], f"Training_Log_{CFG['model_name']}.xlsx")
    metrics_df.to_excel(log_path, index=False)
    print(f"[✔] Training log saved to: {log_path}")

    plot_metrics(history['Training_Loss'],history['Validation_Loss'],history['Training_Accuracy'],history['Validation_Accuracy'])
    return history

# %% [markdown]
# # Start Training

# %%
# run training

history = run_training()
# Out:
# [INFO] Creating train transforms
# [INFO] Input size=(224, 224), mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
#
# [INFO] Creating val/test transforms
# [INFO] Input size=(224, 224), mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
#
#  🚀 Model Name: davit_base.msft_in1k
# Total Class: 2
# Optimizer Used: AdamW
# Initial Learning Rate:0.001
# Batch Size: 32
# Loss Function Used: cross_entropy
# Epoch 1/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 1/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:1: Learning Rate: 0.001000 |
# 📉 Training_loss 0.4075, Training_Accuracy 0.8369 |
# 📈Validation_loss 0.1907, Validation_Accuracy 0.9258
#
#   ↓ 🏆 New best val_loss (0.1907), saved to ./models/davit_base.msft_in1k_best_val_loss.pth
#   ↑ 🔥 New best val_acc (0.9258), saved to ./models/davit_base.msft_in1k_best_val_acc.pth
# Epoch 2/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 2/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:2: Learning Rate: 0.001000 |
# 📉 Training_loss 0.2333, Training_Accuracy 0.9059 |
# 📈Validation_loss 0.1996, Validation_Accuracy 0.9066
# Epoch 3/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 3/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:3: Learning Rate: 0.001000 |
# 📉 Training_loss 0.2038, Training_Accuracy 0.9176 |
# 📈Validation_loss 0.1446, Validation_Accuracy 0.9478
#
#   ↓ 🏆 New best val_loss (0.1446), saved to ./models/davit_base.msft_in1k_best_val_loss.pth
#   ↑ 🔥 New best val_acc (0.9478), saved to ./models/davit_base.msft_in1k_best_val_acc.pth
# Epoch 4/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 4/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:4: Learning Rate: 0.001000 |
# 📉 Training_loss 0.1737, Training_Accuracy 0.9271 |
# 📈Validation_loss 0.1309, Validation_Accuracy 0.9396
#
#   ↓ 🏆 New best val_loss (0.1309), saved to ./models/davit_base.msft_in1k_best_val_loss.pth
# Epoch 5/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 5/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:5: Learning Rate: 0.001000 |
# 📉 Training_loss 0.2064, Training_Accuracy 0.9098 |
# 📈Validation_loss 0.1297, Validation_Accuracy 0.9505
#
#   ↓ 🏆 New best val_loss (0.1297), saved to ./models/davit_base.msft_in1k_best_val_loss.pth
#   ↑ 🔥 New best val_acc (0.9505), saved to ./models/davit_base.msft_in1k_best_val_acc.pth
# Epoch 6/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 6/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:6: Learning Rate: 0.001000 |
# 📉 Training_loss 0.1917, Training_Accuracy 0.9302 |
# 📈Validation_loss 0.1785, Validation_Accuracy 0.9121
# Epoch 7/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 7/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:7: Learning Rate: 0.001000 |
# 📉 Training_loss 0.1547, Training_Accuracy 0.9435 |
# 📈Validation_loss 0.1007, Validation_Accuracy 0.9698
#
#   ↓ 🏆 New best val_loss (0.1007), saved to ./models/davit_base.msft_in1k_best_val_loss.pth
#   ↑ 🔥 New best val_acc (0.9698), saved to ./models/davit_base.msft_in1k_best_val_acc.pth
# Epoch 8/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 8/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:8: Learning Rate: 0.000100 |
# 📉 Training_loss 0.1260, Training_Accuracy 0.9388 |
# 📈Validation_loss 0.0694, Validation_Accuracy 0.9808
#
#   ↓ 🏆 New best val_loss (0.0694), saved to ./models/davit_base.msft_in1k_best_val_loss.pth
#   ↑ 🔥 New best val_acc (0.9808), saved to ./models/davit_base.msft_in1k_best_val_acc.pth
# Epoch 9/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 9/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:9: Learning Rate: 0.000100 |
# 📉 Training_loss 0.0905, Training_Accuracy 0.9678 |
# 📈Validation_loss 0.0659, Validation_Accuracy 0.9808
#
#   ↓ 🏆 New best val_loss (0.0659), saved to ./models/davit_base.msft_in1k_best_val_loss.pth
# Epoch 10/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 10/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:10: Learning Rate: 0.000100 |
# 📉 Training_loss 0.0706, Training_Accuracy 0.9710 |
# 📈Validation_loss 0.0575, Validation_Accuracy 0.9835
#
#   ↓ 🏆 New best val_loss (0.0575), saved to ./models/davit_base.msft_in1k_best_val_loss.pth
#   ↑ 🔥 New best val_acc (0.9835), saved to ./models/davit_base.msft_in1k_best_val_acc.pth
# Epoch 11/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 11/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:11: Learning Rate: 0.000100 |
# 📉 Training_loss 0.0734, Training_Accuracy 0.9710 |
# 📈Validation_loss 0.0652, Validation_Accuracy 0.9780
# Epoch 12/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 12/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:12: Learning Rate: 0.000100 |
# 📉 Training_loss 0.0588, Training_Accuracy 0.9749 |
# 📈Validation_loss 0.0597, Validation_Accuracy 0.9808
# Epoch 13/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 13/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:13: Learning Rate: 0.000100 |
# 📉 Training_loss 0.0543, Training_Accuracy 0.9765 |
# 📈Validation_loss 0.0652, Validation_Accuracy 0.9725
# Epoch 14/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 14/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:14: Learning Rate: 0.000100 |
# 📉 Training_loss 0.0608, Training_Accuracy 0.9757 |
# 📈Validation_loss 0.0735, Validation_Accuracy 0.9808
# Epoch 15/15 Train:   0%|          | 0/40 [00:05<?, ?it/s]
# Epoch 15/15 Validation:   0%|          | 0/12 [00:00<?, ?it/s]
#  ✅ Epoch Number:15: Learning Rate: 0.000010 |
# 📉 Training_loss 0.0520, Training_Accuracy 0.9773 |
# 📈Validation_loss 0.0725, Validation_Accuracy 0.9808
#
#
# Training complete.
# Best Validation_loss: 0.0575,
# Best Validation Loss Epoch Number: 10
# Best Validatio_Accuracy: 0.9835
# Best Validation Accuracy Epoch Number:10
#
# [✔] Training log saved to: ./results/Training_Log_davit_base.msft_in1k.xlsx

# %% [markdown]
# # Load Model From Saved Checkpoint

# %%
def load_model(model_name: str,num_classes: int,load_type: int,path: str) -> torch.nn.Module:
    """
    load_type:
      0 → load a specific epoch checkpoint (requires `epoch` be set)
      1 → load best_val_loss check point
      2 → load best_val_acc  checkpoint
    """
    # 1) build fresh model
    model = get_model(model_name, num_classes, device)

    # 2) pick filename
    if load_type == 1:
        fname = f"{model_name}_best_val_loss.pth"
    elif load_type == 2:
        fname = f"{model_name}_best_val_acc.pth"
    else:
        if epoch is None:
            raise ValueError("`epoch` must be provided when load_type=0")
        fname = f"{model_name}_epoch_{epoch}.pth"

    fn = os.path.join(path, fname)

    # 3) load weights
    state = torch.load(fn, map_location=device)
    model.load_state_dict(state)

    return model

# %% [markdown]
# # Final Evaluation

# %%
# Cell 10: Final Test Evaluation
# choose epoch to load, e.g. best or specific
#epoch_to_test = 3

# Load Type--> 1 --> Best Validation Loss Model Checkpoint Loaded
# Load Type--> 2 --> Best Validation Accuracy Model Checkpoint Loaded

load_type =1

# reload model & data
_, _, test_loader, class_names = get_dataloaders()
model = load_model(CFG['model_name'], len(class_names), load_type, CFG['save_path'])

# evaluate
acc, report_df, conf_df = evaluate_and_save(model, test_loader, class_names, save_dir='./results')

#print(f"Testing Accuracy of {CFG['model_name']} is: ", acc)
# Out:
# [INFO] Creating train transforms
# [INFO] Input size=(224, 224), mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
#
# [INFO] Creating val/test transforms
# [INFO] Input size=(224, 224), mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
#
#  Test Accuracy: 0.9396
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        daisy       0.95      0.91      0.93        77
#    dandelion       0.94      0.96      0.95       105
#
#     accuracy                           0.94       182
#    macro avg       0.94      0.94      0.94       182
# weighted avg       0.94      0.94      0.94       182
#
# Confusion Matrix:
#  [[ 70   7]
#  [  4 101]]
# Confusion matrix saved to: ./results/confusion_matrix_davit_base.msft_in1k.png
# Results saved to: ./results/test_metrics.xlsx
